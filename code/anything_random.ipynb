# %% [markdown]
# # Tartan Data Science Cup
#
#     - Problem: Binary Classification on user's loan_status [Good or Bad]
#     - Team : Anything Random
#     - Members : Nikita Gupta, Maria Rodriguez, Kweonwoo Jung
#     - Prize : AppleTV + USD50 per participant
#     - Period: Feb 04 2017 9AM ~ 6PM

# %%
# data manipulation
import pandas as pd
import numpy as np
import operator

# machine learning (preprocessing, k-fold cross-validation, model training, evaluation)
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import brier_score_loss, roc_auc_score, log_loss
from sklearn.preprocessing import LabelEncoder

# xgboost
import xgboost as xgb

# plot
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # Data Preparation
#     - load data
#     - check loan_status histogram
#     - binarize the target column : 'loan_status'

# %%
# load data
data = pd.read_csv('../input/train.csv')
tst  = pd.read_csv('../input/test.csv')

# %%
# check loan_status histogram
sns.countplot(data['loan_status'])

# %%
# convert 'loan_status' into binary

col = 'loan_status'
positives = ['Fully Paid','Current','In Grace Period']
y = np.zeros(data.shape[0])

for i, row in enumerate(data[col]):
    if row not in positives:
        y[i] = 1    
        
print('# Ratio of positives : {0:.4}% out of 150k'.format((y.sum()/y.shape)[0]))
# Out:
# # Ratio of positives : 0.1014% out of 150k

# %% [markdown]
# # Preprocessing & Feature Engineering
#     - converting categorical variables into numeric variables, preserving the order if necessary
#     - additional feature engineering
#         - distance between today and issue_d, earliest_cr_line
#         - annual_income into bin

# %%
# converting categorical variables into numeric
features = []

# term
col = 'term'
lb = LabelEncoder()
data[col] = lb.fit_transform(data[col])
tst[col] = lb.transform(tst[col])
features.append(col)

# int_rate
col = 'int_rate'
data[col] = data[col].apply(lambda x: x[:-1]).astype(np.float32)
tst[col] = tst[col].apply(lambda x: x[:-1]).astype(np.float32)
features.append(col)

# grade
col = 'grade'
lb = LabelEncoder()
data[col] = lb.fit_transform(data[col])
tst[col] = lb.transform(tst[col])
features.append(col)

# sub_grade
col = 'sub_grade'
lb = LabelEncoder()
data[col] = lb.fit_transform(data[col])
tst[col] = lb.transform(tst[col])
features.append(col)

# emp_length
col = 'emp_length'
temp = data[col].apply(lambda x: x[:2])
temp.replace('n/', 0, inplace=True)
temp.replace('< ', 0.5, inplace=True)
data[col] = temp.astype(np.float32)
temp = tst[col].apply(lambda x: x[:2])
temp.replace('n/', 0, inplace=True)
temp.replace('< ', 0.5, inplace=True)
tst[col] = temp.astype(np.float32)
features.append(col)

# home_ownership
col = 'home_ownership'
lb = LabelEncoder()
data[col] = lb.fit_transform(data[col])
tst[col] = lb.transform(tst[col])
features.append(col)

# verification_status
col = 'verification_status'
lb = LabelEncoder()
data[col] = lb.fit_transform(data[col])
tst[col] = lb.transform(tst[col])
features.append(col)


# issue_d
col = 'issue_d'
months_map = {'Jan':1, 'Feb':2, 'Mar':3, 'Apr':4, 'May':5, 'Jun':6,
              'Jul':7, 'Aug':8, 'Sep':9, 'Oct':10,'Nov':11,'Dec':12}
data['issue_m'] = data[col].apply(lambda x: months_map[x[:3]])
tst['issue_m'] = tst[col].apply(lambda x: months_map[x[:3]])
features.append('issue_m')

data['issue_y'] = data[col].apply(lambda x: x[4:]).astype(np.int32)
tst['issue_y'] = tst[col].apply(lambda x: x[4:]).astype(np.int32)
features.append('issue_y')

# purpose
col = 'purpose'
lb = LabelEncoder()
data[col] = lb.fit_transform(data[col])
tst[col] = lb.transform(tst[col])
features.append(col)

# zip_code
col = 'zip_code'
lb = LabelEncoder()
lb.fit(pd.concat([data[col], tst[col]], axis=0))
data[col] = lb.transform(data[col])
tst[col] = lb.transform(tst[col])
features.append(col)

# addr_state
col = 'addr_state'
lb = LabelEncoder()
data[col] = lb.fit_transform(data[col])
tst[col] = lb.transform(tst[col])
features.append(col)

# earliest_cr_line
col = 'earliest_cr_line'
data['earliest_cr_line_m'] = data[col].apply(lambda x: months_map[x[:3]])
tst['earliest_cr_line_m'] = tst[col].apply(lambda x: months_map[x[:3]])
features.append('earliest_cr_line_m')

data['earliest_cr_line_y'] = data[col].apply(lambda x: x[4:]).astype(np.int32)
tst['earliest_cr_line_y'] = tst[col].apply(lambda x: x[4:]).astype(np.int32)
features.append('earliest_cr_line_y')

# revol_util
col = 'revol_util'
data[col] = data[col].apply(lambda x: str(x).replace('%','')).astype(np.float32).fillna(0)
tst[col] = tst[col].apply(lambda x: str(x).replace('%','')).astype(np.float32).fillna(0)
features.append(col)

# initial_list_status
col = 'initial_list_status'
lb = LabelEncoder()
data[col] = lb.fit_transform(data[col])
tst[col] = lb.transform(tst[col])
features.append(col)

# application_type
col = 'application_type'
lb = LabelEncoder()
data[col] = lb.fit_transform(data[col])
tst[col] = lb.transform(tst[col])
features.append(col)

# %%
# additional feature engineering
# distance from today to issue_d and early_cr_line
data['issue_datestamp'] = ((2017 - 1900)*12 + 2) - (data['issue_m'] + (data['issue_y'] - 1900)*12)
data['early_cr_datestamp'] = ((2017 - 1900)*12 + 2) - (data['earliest_cr_line_m'] + (data['earliest_cr_line_y'] - 1990)*12)
tst['issue_datestamp'] = ((2017 - 1900)*12 + 2) - (tst['issue_m'] + (tst['issue_y'] - 1900)*12)
tst['early_cr_datestamp'] = ((2017 - 1900)*12 + 2) - (tst['earliest_cr_line_m'] + (tst['earliest_cr_line_y'] - 1990)*12)
features.append('issue_datestamp')
features.append('early_cr_datestamp')

def to_bin(x):
    if x < 10000: return 1
    elif x < 30000: return 2
    elif x < 60000: return 3
    elif x < 90000: return 4
    elif x < 120000: return 5
    else: return 6

# annual_inc in bin
col = 'annual_inc'
data['annual_inc_bin'] = data[col].apply(lambda x: to_bin(x))
tst['annual_inc_bin'] = tst[col].apply(lambda x: to_bin(x))
features.append('annual_inc_bin')

# outlier clipping
# dti clip > 99 to 100
data.loc[data['dti'] > 99, 'dti'] = 100
tst.loc[tst['dti'] > 99, 'dti'] = 100

# pub_rec clipt >20 to 20
data.loc[data['pub_rec'] > 20,'pub_rec'] = 20
tst.loc[tst['pub_rec'] > 20,'pub_rec'] = 20

# %% [markdown]
# # Model Evlauation
#     - Benchmark Brier score is 0.1014 for All Zero submission
#     - Evaluting base model with 3-fold cross-validation
#         - evaluate on trn/vld data to avoid overfitting
#         - evaluate linear(logistic regression), tree(random forest, extra trees, xgboost)
#         - evaluate Brier, AUC, Logloss scores

# %%
# benchmark evaluation values for Brier scores to refer

# all zero
bench_m = np.zeros(data.shape[0])
print('# All Zero')
print('\tBrier   : {0:.4f}'.format(brier_score_loss(y, bench_m)))
print('\tAUC     : {0:.4f}'.format(roc_auc_score(y, bench_m)))
print('\tLogloss : {0:.4f}\n'.format(log_loss(y, bench_m)))

# all 0.5
bench_m += 0.5
print('# All 0.5')
print('\tBrier   : {0:.4f}'.format(brier_score_loss(y, bench_m)))
print('\tAUC     : {0:.4f}'.format(roc_auc_score(y, bench_m)))
print('\tLogloss : {0:.4f}\n'.format(log_loss(y, bench_m)))

# all 1.0
bench_m += 0.5
print('# All One')
print('\tBrier   : {0:.4f}'.format(brier_score_loss(y, bench_m)))
print('\tAUC     : {0:.4f}'.format(roc_auc_score(y, bench_m)))
print('\tLogloss : {0:.4f}\n'.format(log_loss(y, bench_m)))
# Out:
# # All Zero
# 	Brier   : 0.1014
# 	AUC     : 0.5000
# 	Logloss : 3.5032
#
# # All 0.5
# 	Brier   : 0.2500
# 	AUC     : 0.5000
# 	Logloss : 0.6931
#
# # All One
# 	Brier   : 0.8986
# 	AUC     : 0.5000
# 	Logloss : 31.0363

# %%
# add numeric features to complete feature set
features.extend(['loan_amnt', 'installment', 'annual_inc', 'dti' ,'delinq_2yrs', 'inq_last_6mths', 'open_acc',
            'pub_rec', 'total_acc'])

# %%
# extract data 
trn = data.as_matrix(columns=features)

# empty lists for storing evaluation results
trn_bri = []; vld_bri = []
trn_auc = []; vld_auc = []
trn_log = []; vld_log = []

# 3-fold cross validation
skf = StratifiedKFold(n_splits=3)
for trn_index, vld_index in skf.split(trn, y):
    
    # split data into trn/vld
    x_trn, x_vld = trn[trn_index], trn[vld_index]
    y_trn, y_vld = y[trn_index], y[vld_index]
    
    # model fit
    model = RandomForestClassifier(max_depth=5, n_jobs=-1, random_state=777)
    # model = LogisticRegression(C=1, n_jobs=-1)
    # model = ExtraTreesClassifier(max_depth=10, n_jobs=-1, random_state=777)
    model.fit(x_trn, y_trn)

    # evaluate trn scores
    trn_pred = model.predict_proba(x_trn)[:,1]
    trn_bri.append(brier_score_loss(y_trn, trn_pred))
    trn_auc.append(roc_auc_score(y_trn, trn_pred))
    trn_log.append(log_loss(y_trn, trn_pred))
    
    # evaluate vld scores
    vld_pred = model.predict_proba(x_vld)[:,1]
    vld_bri.append(brier_score_loss(y_vld, vld_pred))
    vld_auc.append(roc_auc_score(y_vld, vld_pred))
    vld_log.append(log_loss(y_vld, vld_pred))
    
# print evaluations on trn/vld 
print('=' * 50)
print(' TRAIN')
print('-' * 50)
print('# Brier   : {0:.4f} + {0:.2f}'.format(np.mean(trn_bri), np.std(trn_bri)))
print('# AUC     : {0:.4f} + {0:.2f}'.format(np.mean(trn_auc), np.std(trn_auc)))
print('# Logloss : {0:.4f} + {0:.2f}'.format(np.mean(trn_log), np.std(trn_log)))

print('=' * 50)
print(' VALID')
print('-' * 50)
print('# Brier   : {0:.4f} + {0:.2f}'.format(np.mean(vld_bri), np.std(vld_bri)))
print('# AUC     : {0:.4f} + {0:.2f}'.format(np.mean(vld_auc), np.std(vld_auc)))
print('# Logloss : {0:.4f} + {0:.2f}'.format(np.mean(vld_log), np.std(vld_log)))
# Out:
# ==================================================
#  TRAIN
# --------------------------------------------------
# # Brier   : 0.0850 + 0.09
# # AUC     : 0.7382 + 0.74
# # Logloss : 0.2963 + 0.30
# ==================================================
#  VALID
# --------------------------------------------------
# # Brier   : 0.0854 + 0.09
# # AUC     : 0.7320 + 0.73
# # Logloss : 0.2978 + 0.30

# %% [markdown]
# # XGBoost modeling

# %%
# extract data 
trn = data.as_matrix(columns=features)

# empty lists for storing evaluation results
trn_bri = []; vld_bri = []
trn_auc = []; vld_auc = []
trn_log = []; vld_log = []

# store best ntree iteration 
best_ntree = []

# xgboost parameter
param = {
        'objective': 'binary:logistic',
        'eta': 0.02,
        'min_child_weight': 10,
        'max_depth': 5,
        'silent': 1,
        'eval_metric': 'auc',
        'colsample_bytree': 0.8,
        'colsample_bylevel': 0.8,
    }

# 3-fold cross validation
skf = StratifiedKFold(n_splits=3)
for trn_index, vld_index in skf.split(trn, y):
    
    # split data into trn/vld
    x_trn, x_vld = trn[trn_index], trn[vld_index]
    y_trn, y_vld = y[trn_index], y[vld_index]
    
    # convert to xgboost data format
    dtrn = xgb.DMatrix(x_trn, label=y_trn, feature_names=features)
    dvld = xgb.DMatrix(x_vld, label=y_vld, feature_names=features)
    
    # train model
    evallist  = [(dtrn,'train'), (dvld,'eval')]
    xgb_model = xgb.train(param, dtrn, 1000, evals=evallist, early_stopping_rounds=20)    
    
    # record best_iteration count
    best_ntree_limit = xgb_model.best_ntree_limit
    best_ntree.append(best_ntree_limit)
    
    # trn scores
    trn_pred = xgb_model.predict(dtrn)
    trn_bri.append(brier_score_loss(y_trn, trn_pred))
    trn_auc.append(roc_auc_score(y_trn, trn_pred))
    trn_log.append(log_loss(y_trn, trn_pred))
    
    # vld scores
    vld_pred = xgb_model.predict(dvld)
    vld_bri.append(brier_score_loss(y_vld, vld_pred))
    vld_auc.append(roc_auc_score(y_vld, vld_pred))
    vld_log.append(log_loss(y_vld, vld_pred))
    

# print evaluations on trn/vld 
print('=' * 50)
print(' TRAIN')
print('-' * 50)
print('# Brier   : {0:.4f} + {0:.2f}'.format(np.mean(trn_bri), np.std(trn_bri)))
print('# AUC     : {0:.4f} + {0:.2f}'.format(np.mean(trn_auc), np.std(trn_auc)))
print('# Logloss : {0:.4f} + {0:.2f}'.format(np.mean(trn_log), np.std(trn_log)))

print('=' * 50)
print(' VALID')
print('-' * 50)
print('# Brier   : {0:.4f} + {0:.2f}'.format(np.mean(vld_bri), np.std(vld_bri)))
print('# AUC     : {0:.4f} + {0:.2f}'.format(np.mean(vld_auc), np.std(vld_auc)))
print('# Logloss : {0:.4f} + {0:.2f}'.format(np.mean(vld_log), np.std(vld_log)))
# Out:
# [0]	train-auc:0.733048	eval-auc:0.729978
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.73614	eval-auc:0.731921
# [2]	train-auc:0.738371	eval-auc:0.733851
# [3]	train-auc:0.738494	eval-auc:0.733798
# [4]	train-auc:0.738619	eval-auc:0.734444
# [5]	train-auc:0.739448	eval-auc:0.734829
# [6]	train-auc:0.739557	eval-auc:0.734948
# [7]	train-auc:0.739586	eval-auc:0.734919
# [8]	train-auc:0.739826	eval-auc:0.734816
# [9]	train-auc:0.740078	eval-auc:0.735275
# [10]	train-auc:0.740184	eval-auc:0.735361
# [11]	train-auc:0.740066	eval-auc:0.73502
# [12]	train-auc:0.740267	eval-auc:0.73521
# [13]	train-auc:0.740248	eval-auc:0.735314
# [14]	train-auc:0.740693	eval-auc:0.735759
# [15]	train-auc:0.740697	eval-auc:0.735705
# [16]	train-auc:0.740823	eval-auc:0.735859
# [17]	train-auc:0.740889	eval-auc:0.736045
# [18]	train-auc:0.740972	eval-auc:0.73604
# [19]	train-auc:0.741135	eval-auc:0.736028
# [20]	train-auc:0.741208	eval-auc:0.735945
# [21]	train-auc:0.741206	eval-auc:0.736016
# [22]	train-auc:0.741209	eval-auc:0.736024
# [23]	train-auc:0.741271	eval-auc:0.73611
# [24]	train-auc:0.741356	eval-auc:0.736226
# [25]	train-auc:0.741415	eval-auc:0.736269
# [26]	train-auc:0.741396	eval-auc:0.736184
# [27]	train-auc:0.741433	eval-auc:0.736157
# [28]	train-auc:0.741558	eval-auc:0.736247
# [29]	train-auc:0.741647	eval-auc:0.736244
# [30]	train-auc:0.7417	eval-auc:0.736248
# [31]	train-auc:0.741756	eval-auc:0.736189
# [32]	train-auc:0.741747	eval-auc:0.736159
# [33]	train-auc:0.741753	eval-auc:0.736154
# [34]	train-auc:0.741821	eval-auc:0.736191
# [35]	train-auc:0.741847	eval-auc:0.73625
# [36]	train-auc:0.741859	eval-auc:0.736239
# [37]	train-auc:0.74195	eval-auc:0.736334
# [38]	train-auc:0.741984	eval-auc:0.736375
# [39]	train-auc:0.742125	eval-auc:0.73646
# [40]	train-auc:0.742179	eval-auc:0.736468
# [41]	train-auc:0.742246	eval-auc:0.736474
# [42]	train-auc:0.742318	eval-auc:0.736439
# [43]	train-auc:0.742325	eval-auc:0.73643
# [44]	train-auc:0.742434	eval-auc:0.736433
# [45]	train-auc:0.742455	eval-auc:0.736476
# [46]	train-auc:0.742484	eval-auc:0.736465
# [47]	train-auc:0.742609	eval-auc:0.73659
# [48]	train-auc:0.742858	eval-auc:0.736775
# [49]	train-auc:0.742972	eval-auc:0.736886
# [50]	train-auc:0.742996	eval-auc:0.736878
# [51]	train-auc:0.743134	eval-auc:0.736951
# [52]	train-auc:0.743203	eval-auc:0.737003
# [53]	train-auc:0.743204	eval-auc:0.736989
# [54]	train-auc:0.743466	eval-auc:0.737123
# [55]	train-auc:0.743563	eval-auc:0.737128
# [56]	train-auc:0.743684	eval-auc:0.737251
# [57]	train-auc:0.743727	eval-auc:0.737264
# [58]	train-auc:0.743775	eval-auc:0.737294
# [59]	train-auc:0.743814	eval-auc:0.737349
# [60]	train-auc:0.743871	eval-auc:0.737392
# [61]	train-auc:0.743928	eval-auc:0.73744
# [62]	train-auc:0.744002	eval-auc:0.737453
# [63]	train-auc:0.744101	eval-auc:0.737518
# [64]	train-auc:0.744175	eval-auc:0.737628
# [65]	train-auc:0.744224	eval-auc:0.737593
# [66]	train-auc:0.744309	eval-auc:0.737632
# [67]	train-auc:0.744437	eval-auc:0.737732
# [68]	train-auc:0.744544	eval-auc:0.737783
# [69]	train-auc:0.744605	eval-auc:0.737865
# [70]	train-auc:0.744652	eval-auc:0.737832
# [71]	train-auc:0.744723	eval-auc:0.737854
# [72]	train-auc:0.744761	eval-auc:0.737843
# [73]	train-auc:0.744812	eval-auc:0.737884
# [74]	train-auc:0.744902	eval-auc:0.73792
# [75]	train-auc:0.744975	eval-auc:0.737939
# [76]	train-auc:0.745016	eval-auc:0.737971
# [77]	train-auc:0.745104	eval-auc:0.738041
# [78]	train-auc:0.745192	eval-auc:0.738077
# [79]	train-auc:0.745272	eval-auc:0.738124
# [80]	train-auc:0.745271	eval-auc:0.738117
# [81]	train-auc:0.745338	eval-auc:0.738139
# [82]	train-auc:0.745419	eval-auc:0.738161
# [83]	train-auc:0.745475	eval-auc:0.738182
# [84]	train-auc:0.745546	eval-auc:0.738226
# [85]	train-auc:0.745654	eval-auc:0.738322
# [86]	train-auc:0.745737	eval-auc:0.73838
# [87]	train-auc:0.74575	eval-auc:0.738401
# [88]	train-auc:0.74581	eval-auc:0.738432
# [89]	train-auc:0.745881	eval-auc:0.738467
# [90]	train-auc:0.745946	eval-auc:0.738497
# [91]	train-auc:0.746002	eval-auc:0.738516
# [92]	train-auc:0.746089	eval-auc:0.73852
# [93]	train-auc:0.746163	eval-auc:0.738531
# [94]	train-auc:0.746213	eval-auc:0.738526
# [95]	train-auc:0.746257	eval-auc:0.738509
# [96]	train-auc:0.74633	eval-auc:0.738539
# [97]	train-auc:0.746413	eval-auc:0.738556
# [98]	train-auc:0.746497	eval-auc:0.738598
# [99]	train-auc:0.746552	eval-auc:0.7386
# [100]	train-auc:0.746602	eval-auc:0.738604
# [101]	train-auc:0.746683	eval-auc:0.738652
# [102]	train-auc:0.746842	eval-auc:0.738731
# [103]	train-auc:0.7469	eval-auc:0.738761
# [104]	train-auc:0.746948	eval-auc:0.738764
# [105]	train-auc:0.747013	eval-auc:0.738805
# [106]	train-auc:0.747122	eval-auc:0.738914
# [107]	train-auc:0.747193	eval-auc:0.738927
# [108]	train-auc:0.747286	eval-auc:0.738949
# [109]	train-auc:0.747325	eval-auc:0.738994
# [110]	train-auc:0.747416	eval-auc:0.739008
# [111]	train-auc:0.747487	eval-auc:0.739068
# [112]	train-auc:0.747522	eval-auc:0.739067
# [113]	train-auc:0.747571	eval-auc:0.739088
# [114]	train-auc:0.747652	eval-auc:0.739121
# [115]	train-auc:0.747703	eval-auc:0.739111
# [116]	train-auc:0.747792	eval-auc:0.739145
# [117]	train-auc:0.747851	eval-auc:0.739145
# [118]	train-auc:0.74797	eval-auc:0.73917
# [119]	train-auc:0.748042	eval-auc:0.73918
# [120]	train-auc:0.748165	eval-auc:0.739259
# [121]	train-auc:0.748261	eval-auc:0.739313
# [122]	train-auc:0.748404	eval-auc:0.7394
# [123]	train-auc:0.748469	eval-auc:0.739403
# [124]	train-auc:0.748531	eval-auc:0.73941
# [125]	train-auc:0.748582	eval-auc:0.739407
# [126]	train-auc:0.74865	eval-auc:0.739446
# [127]	train-auc:0.748724	eval-auc:0.739461
# [128]	train-auc:0.748787	eval-auc:0.73949
# [129]	train-auc:0.748883	eval-auc:0.739523
# [130]	train-auc:0.748959	eval-auc:0.739539
# [131]	train-auc:0.749068	eval-auc:0.739571
# [132]	train-auc:0.749182	eval-auc:0.739603
# [133]	train-auc:0.749247	eval-auc:0.739663
# [134]	train-auc:0.749355	eval-auc:0.739667
# [135]	train-auc:0.749439	eval-auc:0.739705
# [136]	train-auc:0.749537	eval-auc:0.739727
# [137]	train-auc:0.74966	eval-auc:0.739741
# [138]	train-auc:0.74978	eval-auc:0.739808
# [139]	train-auc:0.749886	eval-auc:0.739884
# [140]	train-auc:0.749969	eval-auc:0.739897
# [141]	train-auc:0.750038	eval-auc:0.739937
# [142]	train-auc:0.75015	eval-auc:0.739984
# [143]	train-auc:0.750239	eval-auc:0.740018
# [144]	train-auc:0.750381	eval-auc:0.740072
# [145]	train-auc:0.750444	eval-auc:0.740079
# [146]	train-auc:0.750521	eval-auc:0.740083
# [147]	train-auc:0.750646	eval-auc:0.740175
# [148]	train-auc:0.750745	eval-auc:0.740239
# [149]	train-auc:0.750839	eval-auc:0.740274
# [150]	train-auc:0.750955	eval-auc:0.740352
# [151]	train-auc:0.751055	eval-auc:0.740386
# [152]	train-auc:0.751119	eval-auc:0.740399
# [153]	train-auc:0.751191	eval-auc:0.74041
# [154]	train-auc:0.751253	eval-auc:0.740409
# [155]	train-auc:0.751325	eval-auc:0.740416
# [156]	train-auc:0.751395	eval-auc:0.740432
# [157]	train-auc:0.751471	eval-auc:0.740468
# [158]	train-auc:0.75156	eval-auc:0.740488
# [159]	train-auc:0.751686	eval-auc:0.740541
# [160]	train-auc:0.751775	eval-auc:0.740552
# [161]	train-auc:0.751843	eval-auc:0.740555
# [162]	train-auc:0.751928	eval-auc:0.740577
# [163]	train-auc:0.752028	eval-auc:0.740587
# [164]	train-auc:0.752138	eval-auc:0.740619
# [165]	train-auc:0.752229	eval-auc:0.740641
# [166]	train-auc:0.75235	eval-auc:0.740655
# [167]	train-auc:0.75242	eval-auc:0.740668
# [168]	train-auc:0.752503	eval-auc:0.740699
# [169]	train-auc:0.75257	eval-auc:0.740711
# [170]	train-auc:0.752683	eval-auc:0.740746
# [171]	train-auc:0.752748	eval-auc:0.740778
# [172]	train-auc:0.752873	eval-auc:0.740805
# [173]	train-auc:0.752999	eval-auc:0.740892
# [174]	train-auc:0.753067	eval-auc:0.740868
# [175]	train-auc:0.753186	eval-auc:0.740884
# [176]	train-auc:0.753285	eval-auc:0.740906
# [177]	train-auc:0.753356	eval-auc:0.740917
# [178]	train-auc:0.753489	eval-auc:0.741
# [179]	train-auc:0.753573	eval-auc:0.74103
# [180]	train-auc:0.753702	eval-auc:0.741067
# [181]	train-auc:0.753782	eval-auc:0.741108
# [182]	train-auc:0.753885	eval-auc:0.741134
# [183]	train-auc:0.753974	eval-auc:0.741189
# [184]	train-auc:0.754141	eval-auc:0.741287
# [185]	train-auc:0.754246	eval-auc:0.741323
# [186]	train-auc:0.754376	eval-auc:0.741351
# [187]	train-auc:0.754457	eval-auc:0.741375
# [188]	train-auc:0.754563	eval-auc:0.741425
# [189]	train-auc:0.75475	eval-auc:0.741462
# [190]	train-auc:0.754816	eval-auc:0.741487
# [191]	train-auc:0.754883	eval-auc:0.74154
# [192]	train-auc:0.755015	eval-auc:0.741593
# [193]	train-auc:0.755128	eval-auc:0.741624
# [194]	train-auc:0.755217	eval-auc:0.741639
# [195]	train-auc:0.755306	eval-auc:0.74164
# [196]	train-auc:0.755431	eval-auc:0.741662
# [197]	train-auc:0.75555	eval-auc:0.741705
# [198]	train-auc:0.755634	eval-auc:0.741747
# [199]	train-auc:0.755776	eval-auc:0.741782
# [200]	train-auc:0.755873	eval-auc:0.7418
# [201]	train-auc:0.756057	eval-auc:0.741873
# [202]	train-auc:0.756104	eval-auc:0.741867
# [203]	train-auc:0.756198	eval-auc:0.741894
# [204]	train-auc:0.756287	eval-auc:0.741888
# [205]	train-auc:0.756435	eval-auc:0.741949
# [206]	train-auc:0.756533	eval-auc:0.741935
# [207]	train-auc:0.756622	eval-auc:0.741985
# [208]	train-auc:0.75672	eval-auc:0.742015
# [209]	train-auc:0.75684	eval-auc:0.742036
# [210]	train-auc:0.756902	eval-auc:0.742041
# [211]	train-auc:0.756986	eval-auc:0.742052
# [212]	train-auc:0.757125	eval-auc:0.742123
# [213]	train-auc:0.757239	eval-auc:0.742148
# [214]	train-auc:0.757374	eval-auc:0.742189
# [215]	train-auc:0.75754	eval-auc:0.742255
# [216]	train-auc:0.757615	eval-auc:0.742274
# [217]	train-auc:0.757701	eval-auc:0.742273
# [218]	train-auc:0.757821	eval-auc:0.7423
# [219]	train-auc:0.757951	eval-auc:0.742333
# [220]	train-auc:0.758015	eval-auc:0.742323
# [221]	train-auc:0.758145	eval-auc:0.742373
# [222]	train-auc:0.758235	eval-auc:0.742382
# [223]	train-auc:0.758301	eval-auc:0.742402
# [224]	train-auc:0.758487	eval-auc:0.742472
# [225]	train-auc:0.758574	eval-auc:0.74248
# [226]	train-auc:0.758713	eval-auc:0.742487
# [227]	train-auc:0.758801	eval-auc:0.742522
# [228]	train-auc:0.758922	eval-auc:0.742526
# [229]	train-auc:0.759018	eval-auc:0.742547
# [230]	train-auc:0.759126	eval-auc:0.7426
# [231]	train-auc:0.759235	eval-auc:0.742625
# [232]	train-auc:0.759326	eval-auc:0.742636
# [233]	train-auc:0.75945	eval-auc:0.742698
# [234]	train-auc:0.759556	eval-auc:0.742738
# [235]	train-auc:0.759678	eval-auc:0.74275
# [236]	train-auc:0.759781	eval-auc:0.742796
# [237]	train-auc:0.759865	eval-auc:0.742806
# [238]	train-auc:0.759984	eval-auc:0.742864
# [239]	train-auc:0.760093	eval-auc:0.742864
# [240]	train-auc:0.760226	eval-auc:0.742898
# [241]	train-auc:0.760281	eval-auc:0.742916
# [242]	train-auc:0.760358	eval-auc:0.742927
# [243]	train-auc:0.760438	eval-auc:0.742928
# [244]	train-auc:0.760475	eval-auc:0.742945
# [245]	train-auc:0.76057	eval-auc:0.742954
# [246]	train-auc:0.760683	eval-auc:0.742961
# [247]	train-auc:0.760728	eval-auc:0.742965
# [248]	train-auc:0.760848	eval-auc:0.743004
# [249]	train-auc:0.760969	eval-auc:0.743063
# [250]	train-auc:0.76108	eval-auc:0.743098
# [251]	train-auc:0.761165	eval-auc:0.743087
# [252]	train-auc:0.761219	eval-auc:0.743114
# [253]	train-auc:0.76129	eval-auc:0.743127
# [254]	train-auc:0.761405	eval-auc:0.743142
# [255]	train-auc:0.761485	eval-auc:0.743166
# [256]	train-auc:0.761543	eval-auc:0.743187
# [257]	train-auc:0.761607	eval-auc:0.743208
# [258]	train-auc:0.761729	eval-auc:0.743254
# [259]	train-auc:0.761851	eval-auc:0.743274
# [260]	train-auc:0.761962	eval-auc:0.743295
# [261]	train-auc:0.761995	eval-auc:0.743283
# [262]	train-auc:0.762095	eval-auc:0.743307
# [263]	train-auc:0.762231	eval-auc:0.743389
# [264]	train-auc:0.76228	eval-auc:0.74341
# [265]	train-auc:0.762323	eval-auc:0.74343
# [266]	train-auc:0.762411	eval-auc:0.743442
# [267]	train-auc:0.762517	eval-auc:0.74345
# [268]	train-auc:0.762583	eval-auc:0.74348
# [269]	train-auc:0.762627	eval-auc:0.74348
# [270]	train-auc:0.76272	eval-auc:0.7435
# [271]	train-auc:0.762804	eval-auc:0.743507
# [272]	train-auc:0.762914	eval-auc:0.743584
# [273]	train-auc:0.763017	eval-auc:0.7436
# [274]	train-auc:0.763065	eval-auc:0.743592
# [275]	train-auc:0.763129	eval-auc:0.743622
# [276]	train-auc:0.763223	eval-auc:0.743626
# [277]	train-auc:0.763274	eval-auc:0.743642
# [278]	train-auc:0.763379	eval-auc:0.743647
# [279]	train-auc:0.763506	eval-auc:0.743729
# [280]	train-auc:0.763531	eval-auc:0.743737
# [281]	train-auc:0.763584	eval-auc:0.743744
# [282]	train-auc:0.763623	eval-auc:0.74376
# [283]	train-auc:0.763667	eval-auc:0.743751
# [284]	train-auc:0.763743	eval-auc:0.743777
# [285]	train-auc:0.763845	eval-auc:0.743795
# [286]	train-auc:0.763931	eval-auc:0.743816
# [287]	train-auc:0.763958	eval-auc:0.74382
# [288]	train-auc:0.764078	eval-auc:0.743827
# [289]	train-auc:0.764202	eval-auc:0.743866
# [290]	train-auc:0.764286	eval-auc:0.743881
# [291]	train-auc:0.764361	eval-auc:0.743906
# [292]	train-auc:0.76444	eval-auc:0.7439
# [293]	train-auc:0.764536	eval-auc:0.74393
# [294]	train-auc:0.764582	eval-auc:0.743934
# [295]	train-auc:0.764677	eval-auc:0.743941
# [296]	train-auc:0.764751	eval-auc:0.743973
# [297]	train-auc:0.76482	eval-auc:0.743998
# [298]	train-auc:0.764847	eval-auc:0.743991
# [299]	train-auc:0.764928	eval-auc:0.743998
# [300]	train-auc:0.76503	eval-auc:0.74401
# [301]	train-auc:0.765064	eval-auc:0.744036
# [302]	train-auc:0.7651	eval-auc:0.744046
# [303]	train-auc:0.765178	eval-auc:0.744048
# [304]	train-auc:0.765263	eval-auc:0.744041
# [305]	train-auc:0.765289	eval-auc:0.744039
# [306]	train-auc:0.765351	eval-auc:0.744048
# [307]	train-auc:0.765437	eval-auc:0.744061
# [308]	train-auc:0.765546	eval-auc:0.744129
# [309]	train-auc:0.76562	eval-auc:0.744148
# [310]	train-auc:0.765697	eval-auc:0.74417
# [311]	train-auc:0.765789	eval-auc:0.744204
# [312]	train-auc:0.765859	eval-auc:0.744198
# [313]	train-auc:0.765966	eval-auc:0.744217
# [314]	train-auc:0.766001	eval-auc:0.744216
# [315]	train-auc:0.766082	eval-auc:0.744211
# [316]	train-auc:0.766104	eval-auc:0.744204
# [317]	train-auc:0.76621	eval-auc:0.744233
# [318]	train-auc:0.766254	eval-auc:0.744235
# [319]	train-auc:0.766304	eval-auc:0.744244
# [320]	train-auc:0.766402	eval-auc:0.744262
# [321]	train-auc:0.766504	eval-auc:0.744278
# [322]	train-auc:0.766616	eval-auc:0.744275
# [323]	train-auc:0.766657	eval-auc:0.744278
# [324]	train-auc:0.766698	eval-auc:0.744271
# [325]	train-auc:0.766843	eval-auc:0.744284
# [326]	train-auc:0.76692	eval-auc:0.744268
# [327]	train-auc:0.767054	eval-auc:0.74427
# [328]	train-auc:0.767146	eval-auc:0.744273
# [329]	train-auc:0.767185	eval-auc:0.744276
# [330]	train-auc:0.767241	eval-auc:0.744276
# [331]	train-auc:0.767335	eval-auc:0.744287
# [332]	train-auc:0.767405	eval-auc:0.744293
# [333]	train-auc:0.767438	eval-auc:0.744305
# [334]	train-auc:0.767493	eval-auc:0.744295
# [335]	train-auc:0.767595	eval-auc:0.744298
# [336]	train-auc:0.767644	eval-auc:0.744303
# [337]	train-auc:0.767702	eval-auc:0.744313
# [338]	train-auc:0.767821	eval-auc:0.744338
# [339]	train-auc:0.767879	eval-auc:0.744335
# [340]	train-auc:0.767932	eval-auc:0.744326
# [341]	train-auc:0.768013	eval-auc:0.744348
# [342]	train-auc:0.768111	eval-auc:0.744346
# [343]	train-auc:0.768174	eval-auc:0.744333
# [344]	train-auc:0.768263	eval-auc:0.744353
# [345]	train-auc:0.768297	eval-auc:0.744348
# [346]	train-auc:0.768418	eval-auc:0.744351
# [347]	train-auc:0.768532	eval-auc:0.744371
# [348]	train-auc:0.768571	eval-auc:0.744375
# [349]	train-auc:0.768606	eval-auc:0.744359
# [350]	train-auc:0.768658	eval-auc:0.744353
# [351]	train-auc:0.768724	eval-auc:0.74435
# [352]	train-auc:0.768779	eval-auc:0.744349
# [353]	train-auc:0.76887	eval-auc:0.744374
# [354]	train-auc:0.768904	eval-auc:0.744351
# [355]	train-auc:0.768993	eval-auc:0.74434
# [356]	train-auc:0.769026	eval-auc:0.74434
# [357]	train-auc:0.769135	eval-auc:0.744358
# [358]	train-auc:0.769196	eval-auc:0.744348
# [359]	train-auc:0.76922	eval-auc:0.744329
# [360]	train-auc:0.769285	eval-auc:0.744339
# [361]	train-auc:0.76934	eval-auc:0.744343
# [362]	train-auc:0.769363	eval-auc:0.744333
# [363]	train-auc:0.769453	eval-auc:0.744316
# [364]	train-auc:0.769531	eval-auc:0.744316
# [365]	train-auc:0.769561	eval-auc:0.744323
# [366]	train-auc:0.769635	eval-auc:0.744345
# [367]	train-auc:0.769649	eval-auc:0.744332
# [368]	train-auc:0.769699	eval-auc:0.744334
# Stopping. Best iteration:
# [348]	train-auc:0.768571	eval-auc:0.744375
#
# [0]	train-auc:0.732599	eval-auc:0.728552
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.734685	eval-auc:0.730243
# [2]	train-auc:0.737009	eval-auc:0.732915
# [3]	train-auc:0.737223	eval-auc:0.733378
# [4]	train-auc:0.737803	eval-auc:0.733828
# [5]	train-auc:0.738186	eval-auc:0.734258
# [6]	train-auc:0.738287	eval-auc:0.734551
# [7]	train-auc:0.738377	eval-auc:0.734736
# [8]	train-auc:0.738725	eval-auc:0.734757
# [9]	train-auc:0.739154	eval-auc:0.735297
# [10]	train-auc:0.739277	eval-auc:0.735321
# [11]	train-auc:0.739337	eval-auc:0.735455
# [12]	train-auc:0.739495	eval-auc:0.735543
# [13]	train-auc:0.7395	eval-auc:0.735519
# [14]	train-auc:0.740103	eval-auc:0.735842
# [15]	train-auc:0.740142	eval-auc:0.736032
# [16]	train-auc:0.740391	eval-auc:0.736252
# [17]	train-auc:0.740521	eval-auc:0.736242
# [18]	train-auc:0.740634	eval-auc:0.736304
# [19]	train-auc:0.740723	eval-auc:0.736478
# [20]	train-auc:0.740709	eval-auc:0.736493
# [21]	train-auc:0.740738	eval-auc:0.736578
# [22]	train-auc:0.740904	eval-auc:0.736687
# [23]	train-auc:0.741036	eval-auc:0.736678
# [24]	train-auc:0.741077	eval-auc:0.736664
# [25]	train-auc:0.74112	eval-auc:0.736619
# [26]	train-auc:0.741172	eval-auc:0.736666
# [27]	train-auc:0.741342	eval-auc:0.736745
# [28]	train-auc:0.741401	eval-auc:0.736688
# [29]	train-auc:0.741482	eval-auc:0.7367
# [30]	train-auc:0.741547	eval-auc:0.736705
# [31]	train-auc:0.741619	eval-auc:0.73669
# [32]	train-auc:0.741665	eval-auc:0.736693
# [33]	train-auc:0.741716	eval-auc:0.73687
# [34]	train-auc:0.741755	eval-auc:0.736943
# [35]	train-auc:0.741776	eval-auc:0.73694
# [36]	train-auc:0.741788	eval-auc:0.736952
# [37]	train-auc:0.741814	eval-auc:0.736906
# [38]	train-auc:0.74179	eval-auc:0.736896
# [39]	train-auc:0.741801	eval-auc:0.736819
# [40]	train-auc:0.741837	eval-auc:0.736798
# [41]	train-auc:0.741907	eval-auc:0.736838
# [42]	train-auc:0.74192	eval-auc:0.736864
# [43]	train-auc:0.74197	eval-auc:0.736883
# [44]	train-auc:0.742083	eval-auc:0.736955
# [45]	train-auc:0.742087	eval-auc:0.73691
# [46]	train-auc:0.74213	eval-auc:0.736904
# [47]	train-auc:0.742185	eval-auc:0.736949
# [48]	train-auc:0.742436	eval-auc:0.737157
# [49]	train-auc:0.742451	eval-auc:0.737182
# [50]	train-auc:0.742515	eval-auc:0.737234
# [51]	train-auc:0.74258	eval-auc:0.737284
# [52]	train-auc:0.742693	eval-auc:0.737438
# [53]	train-auc:0.742728	eval-auc:0.73751
# [54]	train-auc:0.742882	eval-auc:0.737614
# [55]	train-auc:0.742967	eval-auc:0.737731
# [56]	train-auc:0.743097	eval-auc:0.73778
# [57]	train-auc:0.74319	eval-auc:0.737778
# [58]	train-auc:0.743233	eval-auc:0.737793
# [59]	train-auc:0.74326	eval-auc:0.737839
# [60]	train-auc:0.743313	eval-auc:0.737866
# [61]	train-auc:0.743352	eval-auc:0.737947
# [62]	train-auc:0.743454	eval-auc:0.737992
# [63]	train-auc:0.743554	eval-auc:0.737973
# [64]	train-auc:0.743666	eval-auc:0.738001
# [65]	train-auc:0.743712	eval-auc:0.738068
# [66]	train-auc:0.743773	eval-auc:0.738084
# [67]	train-auc:0.743841	eval-auc:0.738144
# [68]	train-auc:0.743921	eval-auc:0.738175
# [69]	train-auc:0.743983	eval-auc:0.738229
# [70]	train-auc:0.744028	eval-auc:0.738281
# [71]	train-auc:0.744071	eval-auc:0.738294
# [72]	train-auc:0.744125	eval-auc:0.738332
# [73]	train-auc:0.744157	eval-auc:0.738355
# [74]	train-auc:0.744256	eval-auc:0.738404
# [75]	train-auc:0.744292	eval-auc:0.738423
# [76]	train-auc:0.744384	eval-auc:0.738466
# [77]	train-auc:0.744475	eval-auc:0.738526
# [78]	train-auc:0.744533	eval-auc:0.738551
# [79]	train-auc:0.744606	eval-auc:0.738523
# [80]	train-auc:0.744689	eval-auc:0.738534
# [81]	train-auc:0.744716	eval-auc:0.738532
# [82]	train-auc:0.744767	eval-auc:0.738552
# [83]	train-auc:0.744801	eval-auc:0.738569
# [84]	train-auc:0.744898	eval-auc:0.7386
# [85]	train-auc:0.744943	eval-auc:0.738598
# [86]	train-auc:0.744999	eval-auc:0.738652
# [87]	train-auc:0.745035	eval-auc:0.738687
# [88]	train-auc:0.745052	eval-auc:0.738701
# [89]	train-auc:0.745103	eval-auc:0.738775
# [90]	train-auc:0.745173	eval-auc:0.738813
# [91]	train-auc:0.745219	eval-auc:0.738859
# [92]	train-auc:0.745298	eval-auc:0.738931
# [93]	train-auc:0.745386	eval-auc:0.738982
# [94]	train-auc:0.745418	eval-auc:0.738989
# [95]	train-auc:0.745479	eval-auc:0.738984
# [96]	train-auc:0.745518	eval-auc:0.738939
# [97]	train-auc:0.745578	eval-auc:0.738958
# [98]	train-auc:0.745633	eval-auc:0.738989
# [99]	train-auc:0.745677	eval-auc:0.738985
# [100]	train-auc:0.745725	eval-auc:0.739033
# [101]	train-auc:0.745783	eval-auc:0.739067
# [102]	train-auc:0.74584	eval-auc:0.739119
# [103]	train-auc:0.745896	eval-auc:0.739154
# [104]	train-auc:0.745946	eval-auc:0.739169
# [105]	train-auc:0.745984	eval-auc:0.739165
# [106]	train-auc:0.746143	eval-auc:0.739213
# [107]	train-auc:0.746195	eval-auc:0.739224
# [108]	train-auc:0.746272	eval-auc:0.739286
# [109]	train-auc:0.746326	eval-auc:0.739306
# [110]	train-auc:0.746425	eval-auc:0.739316
# [111]	train-auc:0.746475	eval-auc:0.739331
# [112]	train-auc:0.74653	eval-auc:0.739334
# [113]	train-auc:0.746579	eval-auc:0.739357
# [114]	train-auc:0.746656	eval-auc:0.739388
# [115]	train-auc:0.746737	eval-auc:0.739428
# [116]	train-auc:0.746811	eval-auc:0.739435
# [117]	train-auc:0.746877	eval-auc:0.73943
# [118]	train-auc:0.747011	eval-auc:0.739505
# [119]	train-auc:0.74709	eval-auc:0.73953
# [120]	train-auc:0.747194	eval-auc:0.739562
# [121]	train-auc:0.747263	eval-auc:0.739564
# [122]	train-auc:0.747346	eval-auc:0.739599
# [123]	train-auc:0.747441	eval-auc:0.739622
# [124]	train-auc:0.747539	eval-auc:0.739664
# [125]	train-auc:0.747612	eval-auc:0.739699
# [126]	train-auc:0.747708	eval-auc:0.739787
# [127]	train-auc:0.747761	eval-auc:0.739799
# [128]	train-auc:0.747798	eval-auc:0.73982
# [129]	train-auc:0.747907	eval-auc:0.739869
# [130]	train-auc:0.747968	eval-auc:0.739895
# [131]	train-auc:0.748053	eval-auc:0.739945
# [132]	train-auc:0.748154	eval-auc:0.74002
# [133]	train-auc:0.748223	eval-auc:0.740056
# [134]	train-auc:0.748332	eval-auc:0.7401
# [135]	train-auc:0.748409	eval-auc:0.740092
# [136]	train-auc:0.74845	eval-auc:0.74009
# [137]	train-auc:0.748509	eval-auc:0.740102
# [138]	train-auc:0.748618	eval-auc:0.740161
# [139]	train-auc:0.748733	eval-auc:0.740205
# [140]	train-auc:0.748801	eval-auc:0.740209
# [141]	train-auc:0.748868	eval-auc:0.740229
# [142]	train-auc:0.74896	eval-auc:0.740317
# [143]	train-auc:0.748998	eval-auc:0.740319
# [144]	train-auc:0.749119	eval-auc:0.740403
# [145]	train-auc:0.7492	eval-auc:0.740406
# [146]	train-auc:0.749279	eval-auc:0.740455
# [147]	train-auc:0.749393	eval-auc:0.740508
# [148]	train-auc:0.749513	eval-auc:0.740527
# [149]	train-auc:0.749578	eval-auc:0.740548
# [150]	train-auc:0.749677	eval-auc:0.740562
# [151]	train-auc:0.749772	eval-auc:0.740607
# [152]	train-auc:0.749876	eval-auc:0.740666
# [153]	train-auc:0.750008	eval-auc:0.740698
# [154]	train-auc:0.750088	eval-auc:0.740747
# [155]	train-auc:0.750167	eval-auc:0.740783
# [156]	train-auc:0.750283	eval-auc:0.74083
# [157]	train-auc:0.750379	eval-auc:0.740896
# [158]	train-auc:0.750469	eval-auc:0.74095
# [159]	train-auc:0.750636	eval-auc:0.741011
# [160]	train-auc:0.750731	eval-auc:0.741023
# [161]	train-auc:0.750811	eval-auc:0.741043
# [162]	train-auc:0.750916	eval-auc:0.741101
# [163]	train-auc:0.751054	eval-auc:0.741119
# [164]	train-auc:0.751127	eval-auc:0.741153
# [165]	train-auc:0.751215	eval-auc:0.741186
# [166]	train-auc:0.751321	eval-auc:0.741245
# [167]	train-auc:0.751395	eval-auc:0.741271
# [168]	train-auc:0.751474	eval-auc:0.741317
# [169]	train-auc:0.751585	eval-auc:0.741376
# [170]	train-auc:0.751687	eval-auc:0.741392
# [171]	train-auc:0.751782	eval-auc:0.741447
# [172]	train-auc:0.751911	eval-auc:0.741494
# [173]	train-auc:0.751999	eval-auc:0.741537
# [174]	train-auc:0.75209	eval-auc:0.741565
# [175]	train-auc:0.752194	eval-auc:0.741596
# [176]	train-auc:0.75229	eval-auc:0.741607
# [177]	train-auc:0.752392	eval-auc:0.741638
# [178]	train-auc:0.752495	eval-auc:0.741673
# [179]	train-auc:0.752607	eval-auc:0.741706
# [180]	train-auc:0.752776	eval-auc:0.741769
# [181]	train-auc:0.752839	eval-auc:0.741749
# [182]	train-auc:0.75293	eval-auc:0.741784
# [183]	train-auc:0.752996	eval-auc:0.741784
# [184]	train-auc:0.753119	eval-auc:0.741808
# [185]	train-auc:0.75325	eval-auc:0.74182
# [186]	train-auc:0.753379	eval-auc:0.741842
# [187]	train-auc:0.753491	eval-auc:0.741858
# [188]	train-auc:0.753591	eval-auc:0.741859
# [189]	train-auc:0.753748	eval-auc:0.741894
# [190]	train-auc:0.753838	eval-auc:0.741908
# [191]	train-auc:0.753896	eval-auc:0.741916
# [192]	train-auc:0.753973	eval-auc:0.741942
# [193]	train-auc:0.754077	eval-auc:0.741967
# [194]	train-auc:0.754201	eval-auc:0.742017
# [195]	train-auc:0.754337	eval-auc:0.742081
# [196]	train-auc:0.754423	eval-auc:0.742109
# [197]	train-auc:0.754518	eval-auc:0.742152
# [198]	train-auc:0.754606	eval-auc:0.742171
# [199]	train-auc:0.754735	eval-auc:0.742233
# [200]	train-auc:0.754816	eval-auc:0.74226
# [201]	train-auc:0.754955	eval-auc:0.742275
# [202]	train-auc:0.755029	eval-auc:0.742309
# [203]	train-auc:0.755135	eval-auc:0.742318
# [204]	train-auc:0.755242	eval-auc:0.742359
# [205]	train-auc:0.755412	eval-auc:0.742426
# [206]	train-auc:0.755487	eval-auc:0.742465
# [207]	train-auc:0.75559	eval-auc:0.742479
# [208]	train-auc:0.755683	eval-auc:0.74251
# [209]	train-auc:0.755802	eval-auc:0.742527
# [210]	train-auc:0.755872	eval-auc:0.74254
# [211]	train-auc:0.755944	eval-auc:0.742558
# [212]	train-auc:0.7561	eval-auc:0.742616
# [213]	train-auc:0.756197	eval-auc:0.742629
# [214]	train-auc:0.756254	eval-auc:0.742658
# [215]	train-auc:0.756404	eval-auc:0.742701
# [216]	train-auc:0.756457	eval-auc:0.74272
# [217]	train-auc:0.756553	eval-auc:0.742734
# [218]	train-auc:0.756647	eval-auc:0.742758
# [219]	train-auc:0.756746	eval-auc:0.742803
# [220]	train-auc:0.756812	eval-auc:0.742823
# [221]	train-auc:0.756886	eval-auc:0.742825
# [222]	train-auc:0.756979	eval-auc:0.742824
# [223]	train-auc:0.757052	eval-auc:0.742838
# [224]	train-auc:0.757195	eval-auc:0.742861
# [225]	train-auc:0.757248	eval-auc:0.742877
# [226]	train-auc:0.757383	eval-auc:0.742936
# [227]	train-auc:0.757457	eval-auc:0.742952
# [228]	train-auc:0.757557	eval-auc:0.742992
# [229]	train-auc:0.757622	eval-auc:0.742992
# [230]	train-auc:0.757728	eval-auc:0.743006
# [231]	train-auc:0.75779	eval-auc:0.743018
# [232]	train-auc:0.757943	eval-auc:0.743084
# [233]	train-auc:0.758036	eval-auc:0.743118
# [234]	train-auc:0.758088	eval-auc:0.743123
# [235]	train-auc:0.758196	eval-auc:0.743146
# [236]	train-auc:0.758238	eval-auc:0.743151
# [237]	train-auc:0.758368	eval-auc:0.743209
# [238]	train-auc:0.758459	eval-auc:0.743261
# [239]	train-auc:0.758542	eval-auc:0.743266
# [240]	train-auc:0.75872	eval-auc:0.743344
# [241]	train-auc:0.758794	eval-auc:0.743357
# [242]	train-auc:0.758902	eval-auc:0.743401
# [243]	train-auc:0.759017	eval-auc:0.743424
# [244]	train-auc:0.759085	eval-auc:0.743445
# [245]	train-auc:0.759154	eval-auc:0.743461
# [246]	train-auc:0.759276	eval-auc:0.743492
# [247]	train-auc:0.759338	eval-auc:0.7435
# [248]	train-auc:0.759461	eval-auc:0.743557
# [249]	train-auc:0.759526	eval-auc:0.743576
# [250]	train-auc:0.759637	eval-auc:0.743596
# [251]	train-auc:0.759754	eval-auc:0.743602
# [252]	train-auc:0.759789	eval-auc:0.743606
# [253]	train-auc:0.759841	eval-auc:0.743625
# [254]	train-auc:0.759993	eval-auc:0.743698
# [255]	train-auc:0.760095	eval-auc:0.74371
# [256]	train-auc:0.760153	eval-auc:0.74375
# [257]	train-auc:0.76026	eval-auc:0.74373
# [258]	train-auc:0.760363	eval-auc:0.743736
# [259]	train-auc:0.760404	eval-auc:0.743734
# [260]	train-auc:0.760521	eval-auc:0.743742
# [261]	train-auc:0.76064	eval-auc:0.743765
# [262]	train-auc:0.760701	eval-auc:0.743794
# [263]	train-auc:0.760789	eval-auc:0.743807
# [264]	train-auc:0.760876	eval-auc:0.743833
# [265]	train-auc:0.760933	eval-auc:0.743839
# [266]	train-auc:0.761015	eval-auc:0.743845
# [267]	train-auc:0.761118	eval-auc:0.74387
# [268]	train-auc:0.761186	eval-auc:0.743885
# [269]	train-auc:0.76127	eval-auc:0.743901
# [270]	train-auc:0.761389	eval-auc:0.743951
# [271]	train-auc:0.761504	eval-auc:0.74397
# [272]	train-auc:0.761557	eval-auc:0.743986
# [273]	train-auc:0.761603	eval-auc:0.743993
# [274]	train-auc:0.761642	eval-auc:0.743999
# [275]	train-auc:0.76173	eval-auc:0.744016
# [276]	train-auc:0.761791	eval-auc:0.74403
# [277]	train-auc:0.761931	eval-auc:0.744044
# [278]	train-auc:0.762003	eval-auc:0.744065
# [279]	train-auc:0.762038	eval-auc:0.744087
# [280]	train-auc:0.762139	eval-auc:0.744125
# [281]	train-auc:0.762217	eval-auc:0.744131
# [282]	train-auc:0.762271	eval-auc:0.74414
# [283]	train-auc:0.762355	eval-auc:0.744148
# [284]	train-auc:0.762433	eval-auc:0.74415
# [285]	train-auc:0.762481	eval-auc:0.744177
# [286]	train-auc:0.762587	eval-auc:0.74423
# [287]	train-auc:0.762615	eval-auc:0.744233
# [288]	train-auc:0.76273	eval-auc:0.744269
# [289]	train-auc:0.762819	eval-auc:0.744281
# [290]	train-auc:0.762922	eval-auc:0.744287
# [291]	train-auc:0.762996	eval-auc:0.744287
# [292]	train-auc:0.763107	eval-auc:0.744322
# [293]	train-auc:0.763159	eval-auc:0.744341
# [294]	train-auc:0.763208	eval-auc:0.744364
# [295]	train-auc:0.763295	eval-auc:0.744375
# [296]	train-auc:0.76336	eval-auc:0.744382
# [297]	train-auc:0.763436	eval-auc:0.744396
# [298]	train-auc:0.763472	eval-auc:0.744381
# [299]	train-auc:0.763561	eval-auc:0.744392
# [300]	train-auc:0.763577	eval-auc:0.744393
# [301]	train-auc:0.763696	eval-auc:0.74443
# [302]	train-auc:0.763764	eval-auc:0.744424
# [303]	train-auc:0.76382	eval-auc:0.744439
# [304]	train-auc:0.7639	eval-auc:0.744442
# [305]	train-auc:0.76392	eval-auc:0.744428
# [306]	train-auc:0.764033	eval-auc:0.74446
# [307]	train-auc:0.764074	eval-auc:0.744465
# [308]	train-auc:0.764181	eval-auc:0.744491
# [309]	train-auc:0.764271	eval-auc:0.744486
# [310]	train-auc:0.764365	eval-auc:0.74451
# [311]	train-auc:0.764437	eval-auc:0.744529
# [312]	train-auc:0.764469	eval-auc:0.744522
# [313]	train-auc:0.764554	eval-auc:0.744539
# [314]	train-auc:0.764596	eval-auc:0.744554
# [315]	train-auc:0.764645	eval-auc:0.744544
# [316]	train-auc:0.764723	eval-auc:0.744558
# [317]	train-auc:0.764809	eval-auc:0.744563
# [318]	train-auc:0.764837	eval-auc:0.744568
# [319]	train-auc:0.764912	eval-auc:0.744582
# [320]	train-auc:0.764979	eval-auc:0.744581
# [321]	train-auc:0.765015	eval-auc:0.744584
# [322]	train-auc:0.765088	eval-auc:0.744568
# [323]	train-auc:0.76513	eval-auc:0.744555
# [324]	train-auc:0.765242	eval-auc:0.744576
# [325]	train-auc:0.765302	eval-auc:0.744599
# [326]	train-auc:0.765382	eval-auc:0.744602
# [327]	train-auc:0.765425	eval-auc:0.744613
# [328]	train-auc:0.765507	eval-auc:0.744642
# [329]	train-auc:0.765563	eval-auc:0.744637
# [330]	train-auc:0.765646	eval-auc:0.744648
# [331]	train-auc:0.765711	eval-auc:0.744666
# [332]	train-auc:0.765745	eval-auc:0.744679
# [333]	train-auc:0.765805	eval-auc:0.744687
# [334]	train-auc:0.765838	eval-auc:0.744686
# [335]	train-auc:0.765927	eval-auc:0.744656
# [336]	train-auc:0.765991	eval-auc:0.744651
# [337]	train-auc:0.766027	eval-auc:0.744665
# [338]	train-auc:0.766083	eval-auc:0.744681
# [339]	train-auc:0.766119	eval-auc:0.744671
# [340]	train-auc:0.766166	eval-auc:0.744675
# [341]	train-auc:0.766204	eval-auc:0.744663
# [342]	train-auc:0.766291	eval-auc:0.744673
# [343]	train-auc:0.766372	eval-auc:0.7447
# [344]	train-auc:0.766384	eval-auc:0.744692
# [345]	train-auc:0.766419	eval-auc:0.744682
# [346]	train-auc:0.766499	eval-auc:0.744704
# [347]	train-auc:0.766538	eval-auc:0.744707
# [348]	train-auc:0.766586	eval-auc:0.744702
# [349]	train-auc:0.766655	eval-auc:0.744688
# [350]	train-auc:0.766729	eval-auc:0.744702
# [351]	train-auc:0.766745	eval-auc:0.744693
# [352]	train-auc:0.766794	eval-auc:0.744686
# [353]	train-auc:0.766898	eval-auc:0.74469
# [354]	train-auc:0.766967	eval-auc:0.744695
# [355]	train-auc:0.767017	eval-auc:0.744702
# [356]	train-auc:0.767101	eval-auc:0.744713
# [357]	train-auc:0.767113	eval-auc:0.744703
# [358]	train-auc:0.76718	eval-auc:0.744722
# [359]	train-auc:0.767198	eval-auc:0.744725
# [360]	train-auc:0.767263	eval-auc:0.744745
# [361]	train-auc:0.767317	eval-auc:0.744739
# [362]	train-auc:0.767386	eval-auc:0.74473
# [363]	train-auc:0.767396	eval-auc:0.744721
# [364]	train-auc:0.767469	eval-auc:0.744727
# [365]	train-auc:0.767527	eval-auc:0.744725
# [366]	train-auc:0.767598	eval-auc:0.74471
# [367]	train-auc:0.767683	eval-auc:0.744729
# [368]	train-auc:0.767754	eval-auc:0.744759
# [369]	train-auc:0.767827	eval-auc:0.744766
# [370]	train-auc:0.767841	eval-auc:0.744759
# [371]	train-auc:0.76789	eval-auc:0.744762
# [372]	train-auc:0.767982	eval-auc:0.744783
# [373]	train-auc:0.768018	eval-auc:0.744788
# [374]	train-auc:0.76809	eval-auc:0.744779
# [375]	train-auc:0.768133	eval-auc:0.744769
# [376]	train-auc:0.768165	eval-auc:0.744788
# [377]	train-auc:0.768236	eval-auc:0.744787
# [378]	train-auc:0.768249	eval-auc:0.744785
# [379]	train-auc:0.76826	eval-auc:0.744776
# [380]	train-auc:0.76836	eval-auc:0.744785
# [381]	train-auc:0.768423	eval-auc:0.744801
# [382]	train-auc:0.768516	eval-auc:0.744812
# [383]	train-auc:0.768581	eval-auc:0.744836
# [384]	train-auc:0.768599	eval-auc:0.74483
# [385]	train-auc:0.768646	eval-auc:0.744821
# [386]	train-auc:0.768725	eval-auc:0.744831
# [387]	train-auc:0.768797	eval-auc:0.74483
# [388]	train-auc:0.768924	eval-auc:0.744844
# [389]	train-auc:0.768962	eval-auc:0.74484
# [390]	train-auc:0.769048	eval-auc:0.744857
# [391]	train-auc:0.769097	eval-auc:0.744846
# [392]	train-auc:0.769145	eval-auc:0.744845
# [393]	train-auc:0.769159	eval-auc:0.744833
# [394]	train-auc:0.769207	eval-auc:0.744822
# [395]	train-auc:0.769277	eval-auc:0.744828
# [396]	train-auc:0.769354	eval-auc:0.744846
# [397]	train-auc:0.769434	eval-auc:0.744854
# [398]	train-auc:0.769518	eval-auc:0.744844
# [399]	train-auc:0.769587	eval-auc:0.744836
# [400]	train-auc:0.769663	eval-auc:0.744844
# [401]	train-auc:0.769705	eval-auc:0.744852
# [402]	train-auc:0.769758	eval-auc:0.744863
# [403]	train-auc:0.769794	eval-auc:0.744856
# [404]	train-auc:0.769852	eval-auc:0.744868
# [405]	train-auc:0.769904	eval-auc:0.744875
# [406]	train-auc:0.769987	eval-auc:0.744861
# [407]	train-auc:0.770007	eval-auc:0.744858
# [408]	train-auc:0.770081	eval-auc:0.744861
# [409]	train-auc:0.770114	eval-auc:0.744865
# [410]	train-auc:0.770176	eval-auc:0.744881
# [411]	train-auc:0.770287	eval-auc:0.744859
# [412]	train-auc:0.770317	eval-auc:0.744859
# [413]	train-auc:0.770403	eval-auc:0.744884
# [414]	train-auc:0.770456	eval-auc:0.744881
# [415]	train-auc:0.770525	eval-auc:0.744886
# [416]	train-auc:0.770584	eval-auc:0.744887
# [417]	train-auc:0.770634	eval-auc:0.744879
# [418]	train-auc:0.770704	eval-auc:0.744881
# [419]	train-auc:0.770741	eval-auc:0.744903
# [420]	train-auc:0.770804	eval-auc:0.744894
# [421]	train-auc:0.770845	eval-auc:0.744902
# [422]	train-auc:0.770887	eval-auc:0.744913
# [423]	train-auc:0.770933	eval-auc:0.744896
# [424]	train-auc:0.770974	eval-auc:0.744883
# [425]	train-auc:0.770999	eval-auc:0.744878
# [426]	train-auc:0.771039	eval-auc:0.744897
# [427]	train-auc:0.771097	eval-auc:0.744908
# [428]	train-auc:0.771175	eval-auc:0.744918
# [429]	train-auc:0.771252	eval-auc:0.744932
# [430]	train-auc:0.771277	eval-auc:0.744932
# [431]	train-auc:0.771318	eval-auc:0.744909
# [432]	train-auc:0.771341	eval-auc:0.744913
# [433]	train-auc:0.771397	eval-auc:0.744916
# [434]	train-auc:0.771446	eval-auc:0.744931
# [435]	train-auc:0.771495	eval-auc:0.744919
# [436]	train-auc:0.771554	eval-auc:0.744928
# [437]	train-auc:0.771638	eval-auc:0.744926
# [438]	train-auc:0.771689	eval-auc:0.744934
# [439]	train-auc:0.771755	eval-auc:0.744927
# [440]	train-auc:0.771815	eval-auc:0.744954
# [441]	train-auc:0.771852	eval-auc:0.744956
# [442]	train-auc:0.771872	eval-auc:0.744946
# [443]	train-auc:0.771959	eval-auc:0.744952
# [444]	train-auc:0.772031	eval-auc:0.744947
# [445]	train-auc:0.77205	eval-auc:0.744946
# [446]	train-auc:0.772111	eval-auc:0.744927
# [447]	train-auc:0.772218	eval-auc:0.744934
# [448]	train-auc:0.772315	eval-auc:0.744931
# [449]	train-auc:0.772346	eval-auc:0.744926
# [450]	train-auc:0.772394	eval-auc:0.744938
# [451]	train-auc:0.772437	eval-auc:0.744958
# [452]	train-auc:0.772481	eval-auc:0.744952
# [453]	train-auc:0.772516	eval-auc:0.744943
# [454]	train-auc:0.772547	eval-auc:0.744942
# [455]	train-auc:0.772582	eval-auc:0.744943
# [456]	train-auc:0.77266	eval-auc:0.744937
# [457]	train-auc:0.772706	eval-auc:0.744932
# [458]	train-auc:0.772811	eval-auc:0.744941
# [459]	train-auc:0.772875	eval-auc:0.74493
# [460]	train-auc:0.772894	eval-auc:0.744928
# [461]	train-auc:0.77294	eval-auc:0.744935
# [462]	train-auc:0.773028	eval-auc:0.744933
# [463]	train-auc:0.773061	eval-auc:0.744933
# [464]	train-auc:0.77308	eval-auc:0.744927
# [465]	train-auc:0.773142	eval-auc:0.744927
# [466]	train-auc:0.773172	eval-auc:0.744928
# [467]	train-auc:0.773253	eval-auc:0.744946
# [468]	train-auc:0.773286	eval-auc:0.744946
# [469]	train-auc:0.773379	eval-auc:0.744943
# [470]	train-auc:0.773428	eval-auc:0.74497
# [471]	train-auc:0.773475	eval-auc:0.744968
# [472]	train-auc:0.773511	eval-auc:0.744953
# [473]	train-auc:0.77358	eval-auc:0.744953
# [474]	train-auc:0.773618	eval-auc:0.744942
# [475]	train-auc:0.773656	eval-auc:0.744932
# [476]	train-auc:0.773713	eval-auc:0.744927
# [477]	train-auc:0.773746	eval-auc:0.744923
# [478]	train-auc:0.773821	eval-auc:0.74494
# [479]	train-auc:0.773862	eval-auc:0.744935
# [480]	train-auc:0.773938	eval-auc:0.744925
# [481]	train-auc:0.773958	eval-auc:0.744929
# [482]	train-auc:0.773993	eval-auc:0.744928
# [483]	train-auc:0.774019	eval-auc:0.744926
# [484]	train-auc:0.774092	eval-auc:0.744947
# [485]	train-auc:0.774174	eval-auc:0.744973
# [486]	train-auc:0.774246	eval-auc:0.744982
# [487]	train-auc:0.774291	eval-auc:0.744993
# [488]	train-auc:0.774405	eval-auc:0.74499
# [489]	train-auc:0.774486	eval-auc:0.744999
# [490]	train-auc:0.774619	eval-auc:0.745016
# [491]	train-auc:0.774681	eval-auc:0.745026
# [492]	train-auc:0.774698	eval-auc:0.745024
# [493]	train-auc:0.774709	eval-auc:0.745019
# [494]	train-auc:0.774774	eval-auc:0.745014
# [495]	train-auc:0.774799	eval-auc:0.745019
# [496]	train-auc:0.774839	eval-auc:0.745029
# [497]	train-auc:0.774906	eval-auc:0.74503
# [498]	train-auc:0.774941	eval-auc:0.745035
# [499]	train-auc:0.775001	eval-auc:0.745056
# [500]	train-auc:0.775017	eval-auc:0.745053
# [501]	train-auc:0.775032	eval-auc:0.745053
# [502]	train-auc:0.775099	eval-auc:0.745042
# [503]	train-auc:0.775132	eval-auc:0.745052
# [504]	train-auc:0.775198	eval-auc:0.74505
# [505]	train-auc:0.775261	eval-auc:0.745067
# [506]	train-auc:0.775303	eval-auc:0.745092
# [507]	train-auc:0.77538	eval-auc:0.745089
# [508]	train-auc:0.775421	eval-auc:0.745082
# [509]	train-auc:0.775435	eval-auc:0.745082
# [510]	train-auc:0.775504	eval-auc:0.745084
# [511]	train-auc:0.775547	eval-auc:0.745086
# [512]	train-auc:0.775577	eval-auc:0.745087
# [513]	train-auc:0.775594	eval-auc:0.745092
# [514]	train-auc:0.775612	eval-auc:0.745095
# [515]	train-auc:0.775652	eval-auc:0.745111
# [516]	train-auc:0.775761	eval-auc:0.745131
# [517]	train-auc:0.77578	eval-auc:0.745123
# [518]	train-auc:0.775826	eval-auc:0.74512
# [519]	train-auc:0.775886	eval-auc:0.74513
# [520]	train-auc:0.775904	eval-auc:0.745127
# [521]	train-auc:0.775936	eval-auc:0.74513
# [522]	train-auc:0.77596	eval-auc:0.745131
# [523]	train-auc:0.776044	eval-auc:0.745143
# [524]	train-auc:0.776113	eval-auc:0.745145
# [525]	train-auc:0.776135	eval-auc:0.745146
# [526]	train-auc:0.776147	eval-auc:0.74514
# [527]	train-auc:0.776169	eval-auc:0.745146
# [528]	train-auc:0.776276	eval-auc:0.745157
# [529]	train-auc:0.77629	eval-auc:0.745156
# [530]	train-auc:0.776363	eval-auc:0.745181
# [531]	train-auc:0.776397	eval-auc:0.745179
# [532]	train-auc:0.776423	eval-auc:0.745175
# [533]	train-auc:0.776463	eval-auc:0.74517
# [534]	train-auc:0.776539	eval-auc:0.745155
# [535]	train-auc:0.776594	eval-auc:0.745162
# [536]	train-auc:0.776692	eval-auc:0.745184
# [537]	train-auc:0.776717	eval-auc:0.745187
# [538]	train-auc:0.776768	eval-auc:0.745187
# [539]	train-auc:0.776789	eval-auc:0.745175
# [540]	train-auc:0.776809	eval-auc:0.74518
# [541]	train-auc:0.776851	eval-auc:0.745192
# [542]	train-auc:0.776893	eval-auc:0.745193
# [543]	train-auc:0.776939	eval-auc:0.745168
# [544]	train-auc:0.777027	eval-auc:0.745187
# [545]	train-auc:0.777058	eval-auc:0.745198
# [546]	train-auc:0.777118	eval-auc:0.745198
# [547]	train-auc:0.777135	eval-auc:0.745205
# [548]	train-auc:0.777151	eval-auc:0.745195
# [549]	train-auc:0.777216	eval-auc:0.745201
# [550]	train-auc:0.7773	eval-auc:0.745221
# [551]	train-auc:0.777328	eval-auc:0.74523
# [552]	train-auc:0.777363	eval-auc:0.745229
# [553]	train-auc:0.777377	eval-auc:0.745226
# [554]	train-auc:0.777454	eval-auc:0.745235
# [555]	train-auc:0.777491	eval-auc:0.745236
# [556]	train-auc:0.777573	eval-auc:0.745232
# [557]	train-auc:0.777611	eval-auc:0.745253
# [558]	train-auc:0.77769	eval-auc:0.745274
# [559]	train-auc:0.777722	eval-auc:0.745276
# [560]	train-auc:0.777735	eval-auc:0.745266
# [561]	train-auc:0.777766	eval-auc:0.745287
# [562]	train-auc:0.777848	eval-auc:0.745305
# [563]	train-auc:0.777878	eval-auc:0.745308
# [564]	train-auc:0.777909	eval-auc:0.745313
# [565]	train-auc:0.777923	eval-auc:0.745315
# [566]	train-auc:0.777957	eval-auc:0.745313
# [567]	train-auc:0.77802	eval-auc:0.745312
# [568]	train-auc:0.778081	eval-auc:0.745328
# [569]	train-auc:0.778098	eval-auc:0.745314
# [570]	train-auc:0.778143	eval-auc:0.745305
# [571]	train-auc:0.77816	eval-auc:0.74531
# [572]	train-auc:0.778172	eval-auc:0.745302
# [573]	train-auc:0.778217	eval-auc:0.745284
# [574]	train-auc:0.778261	eval-auc:0.745275
# [575]	train-auc:0.778357	eval-auc:0.745289
# [576]	train-auc:0.778391	eval-auc:0.745295
# [577]	train-auc:0.77841	eval-auc:0.745288
# [578]	train-auc:0.778428	eval-auc:0.745291
# [579]	train-auc:0.778459	eval-auc:0.745283
# [580]	train-auc:0.778479	eval-auc:0.745278
# [581]	train-auc:0.778539	eval-auc:0.745287
# [582]	train-auc:0.778614	eval-auc:0.745306
# [583]	train-auc:0.778639	eval-auc:0.745305
# [584]	train-auc:0.778691	eval-auc:0.745315
# [585]	train-auc:0.778756	eval-auc:0.74532
# [586]	train-auc:0.778831	eval-auc:0.745325
# [587]	train-auc:0.778917	eval-auc:0.745327
# [588]	train-auc:0.77894	eval-auc:0.745335
# [589]	train-auc:0.778954	eval-auc:0.745336
# [590]	train-auc:0.778968	eval-auc:0.745332
# [591]	train-auc:0.779041	eval-auc:0.745326
# [592]	train-auc:0.779073	eval-auc:0.745326
# [593]	train-auc:0.779164	eval-auc:0.745328
# [594]	train-auc:0.779226	eval-auc:0.74534
# [595]	train-auc:0.779295	eval-auc:0.745325
# [596]	train-auc:0.779321	eval-auc:0.745326
# [597]	train-auc:0.77939	eval-auc:0.745314
# [598]	train-auc:0.779469	eval-auc:0.745319
# [599]	train-auc:0.779543	eval-auc:0.745327
# [600]	train-auc:0.779582	eval-auc:0.745322
# [601]	train-auc:0.779655	eval-auc:0.745346
# [602]	train-auc:0.779713	eval-auc:0.745353
# [603]	train-auc:0.779738	eval-auc:0.745342
# [604]	train-auc:0.779771	eval-auc:0.745346
# [605]	train-auc:0.779802	eval-auc:0.745343
# [606]	train-auc:0.779804	eval-auc:0.745344
# [607]	train-auc:0.779827	eval-auc:0.745344
# [608]	train-auc:0.779842	eval-auc:0.745335
# [609]	train-auc:0.779887	eval-auc:0.745335
# [610]	train-auc:0.779924	eval-auc:0.745344
# [611]	train-auc:0.779968	eval-auc:0.745352
# [612]	train-auc:0.779986	eval-auc:0.74536
# [613]	train-auc:0.780025	eval-auc:0.745362
# [614]	train-auc:0.78008	eval-auc:0.745375
# [615]	train-auc:0.780109	eval-auc:0.745379
# [616]	train-auc:0.780147	eval-auc:0.745391
# [617]	train-auc:0.780208	eval-auc:0.745404
# [618]	train-auc:0.780217	eval-auc:0.745403
# [619]	train-auc:0.780232	eval-auc:0.745404
# [620]	train-auc:0.780255	eval-auc:0.745393
# [621]	train-auc:0.780308	eval-auc:0.745405
# [622]	train-auc:0.780345	eval-auc:0.745413
# [623]	train-auc:0.780427	eval-auc:0.745422
# [624]	train-auc:0.780442	eval-auc:0.745411
# [625]	train-auc:0.780474	eval-auc:0.745416
# [626]	train-auc:0.780514	eval-auc:0.745418
# [627]	train-auc:0.78057	eval-auc:0.745423
# [628]	train-auc:0.780605	eval-auc:0.745425
# [629]	train-auc:0.780634	eval-auc:0.745426
# [630]	train-auc:0.78067	eval-auc:0.745421
# [631]	train-auc:0.780743	eval-auc:0.745432
# [632]	train-auc:0.780811	eval-auc:0.745413
# [633]	train-auc:0.78082	eval-auc:0.745411
# [634]	train-auc:0.780845	eval-auc:0.7454
# [635]	train-auc:0.78087	eval-auc:0.745401
# [636]	train-auc:0.780935	eval-auc:0.745392
# [637]	train-auc:0.780945	eval-auc:0.745389
# [638]	train-auc:0.781031	eval-auc:0.745384
# [639]	train-auc:0.781068	eval-auc:0.745382
# [640]	train-auc:0.781089	eval-auc:0.745382
# [641]	train-auc:0.781171	eval-auc:0.745386
# [642]	train-auc:0.781254	eval-auc:0.745389
# [643]	train-auc:0.781302	eval-auc:0.745394
# [644]	train-auc:0.781369	eval-auc:0.745398
# [645]	train-auc:0.78142	eval-auc:0.745419
# [646]	train-auc:0.781446	eval-auc:0.745426
# [647]	train-auc:0.781527	eval-auc:0.745456
# [648]	train-auc:0.781591	eval-auc:0.745452
# [649]	train-auc:0.78164	eval-auc:0.745452
# [650]	train-auc:0.781653	eval-auc:0.745459
# [651]	train-auc:0.781669	eval-auc:0.745454
# [652]	train-auc:0.781726	eval-auc:0.745447
# [653]	train-auc:0.781777	eval-auc:0.745444
# [654]	train-auc:0.781838	eval-auc:0.745447
# [655]	train-auc:0.781894	eval-auc:0.745448
# [656]	train-auc:0.781918	eval-auc:0.745451
# [657]	train-auc:0.781946	eval-auc:0.745445
# [658]	train-auc:0.781957	eval-auc:0.745447
# [659]	train-auc:0.782021	eval-auc:0.74545
# [660]	train-auc:0.782121	eval-auc:0.745456
# [661]	train-auc:0.782178	eval-auc:0.745468
# [662]	train-auc:0.78223	eval-auc:0.745467
# [663]	train-auc:0.782249	eval-auc:0.74546
# [664]	train-auc:0.782288	eval-auc:0.745474
# [665]	train-auc:0.782369	eval-auc:0.745485
# [666]	train-auc:0.782392	eval-auc:0.745484
# [667]	train-auc:0.782474	eval-auc:0.745483
# [668]	train-auc:0.782493	eval-auc:0.74548
# [669]	train-auc:0.782511	eval-auc:0.745477
# [670]	train-auc:0.782539	eval-auc:0.745474
# [671]	train-auc:0.782569	eval-auc:0.745475
# [672]	train-auc:0.782629	eval-auc:0.745467
# [673]	train-auc:0.782698	eval-auc:0.745471
# [674]	train-auc:0.782733	eval-auc:0.745472
# [675]	train-auc:0.782806	eval-auc:0.74547
# [676]	train-auc:0.782831	eval-auc:0.745455
# [677]	train-auc:0.782871	eval-auc:0.745449
# [678]	train-auc:0.7829	eval-auc:0.745446
# [679]	train-auc:0.782987	eval-auc:0.745451
# [680]	train-auc:0.78301	eval-auc:0.745444
# [681]	train-auc:0.783132	eval-auc:0.74544
# [682]	train-auc:0.78318	eval-auc:0.745438
# [683]	train-auc:0.78319	eval-auc:0.745428
# [684]	train-auc:0.783242	eval-auc:0.745425
# [685]	train-auc:0.783284	eval-auc:0.74542
# Stopping. Best iteration:
# [665]	train-auc:0.782369	eval-auc:0.745485
#
# [0]	train-auc:0.735849	eval-auc:0.722468
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.737216	eval-auc:0.7234
# [2]	train-auc:0.739117	eval-auc:0.725662
# [3]	train-auc:0.740005	eval-auc:0.726688
# [4]	train-auc:0.740566	eval-auc:0.72706
# [5]	train-auc:0.740916	eval-auc:0.727373
# [6]	train-auc:0.74108	eval-auc:0.727671
# [7]	train-auc:0.741352	eval-auc:0.728195
# [8]	train-auc:0.741434	eval-auc:0.728234
# [9]	train-auc:0.741762	eval-auc:0.728599
# [10]	train-auc:0.741953	eval-auc:0.728958
# [11]	train-auc:0.74233	eval-auc:0.729385
# [12]	train-auc:0.742526	eval-auc:0.729478
# [13]	train-auc:0.742655	eval-auc:0.729515
# [14]	train-auc:0.742982	eval-auc:0.729491
# [15]	train-auc:0.743163	eval-auc:0.729806
# [16]	train-auc:0.743341	eval-auc:0.729982
# [17]	train-auc:0.743433	eval-auc:0.73001
# [18]	train-auc:0.743556	eval-auc:0.729908
# [19]	train-auc:0.743696	eval-auc:0.730135
# [20]	train-auc:0.74375	eval-auc:0.730256
# [21]	train-auc:0.743728	eval-auc:0.730201
# [22]	train-auc:0.743862	eval-auc:0.7303
# [23]	train-auc:0.744022	eval-auc:0.730241
# [24]	train-auc:0.744126	eval-auc:0.730179
# [25]	train-auc:0.74415	eval-auc:0.730253
# [26]	train-auc:0.744201	eval-auc:0.730425
# [27]	train-auc:0.744295	eval-auc:0.730557
# [28]	train-auc:0.744319	eval-auc:0.730577
# [29]	train-auc:0.74433	eval-auc:0.73053
# [30]	train-auc:0.744368	eval-auc:0.730551
# [31]	train-auc:0.744365	eval-auc:0.730515
# [32]	train-auc:0.744377	eval-auc:0.730413
# [33]	train-auc:0.744457	eval-auc:0.730436
# [34]	train-auc:0.744446	eval-auc:0.730391
# [35]	train-auc:0.744484	eval-auc:0.73035
# [36]	train-auc:0.74448	eval-auc:0.730285
# [37]	train-auc:0.744508	eval-auc:0.730278
# [38]	train-auc:0.744543	eval-auc:0.730276
# [39]	train-auc:0.744565	eval-auc:0.730234
# [40]	train-auc:0.744696	eval-auc:0.730324
# [41]	train-auc:0.744873	eval-auc:0.730449
# [42]	train-auc:0.744956	eval-auc:0.730535
# [43]	train-auc:0.745062	eval-auc:0.730595
# [44]	train-auc:0.745174	eval-auc:0.730725
# [45]	train-auc:0.74525	eval-auc:0.73082
# [46]	train-auc:0.745334	eval-auc:0.730876
# [47]	train-auc:0.745405	eval-auc:0.730964
# [48]	train-auc:0.745663	eval-auc:0.731188
# [49]	train-auc:0.745713	eval-auc:0.731134
# [50]	train-auc:0.745834	eval-auc:0.731205
# [51]	train-auc:0.745886	eval-auc:0.731286
# [52]	train-auc:0.746007	eval-auc:0.731348
# [53]	train-auc:0.746038	eval-auc:0.731389
# [54]	train-auc:0.746212	eval-auc:0.731396
# [55]	train-auc:0.746301	eval-auc:0.731388
# [56]	train-auc:0.746366	eval-auc:0.731453
# [57]	train-auc:0.746396	eval-auc:0.731453
# [58]	train-auc:0.746424	eval-auc:0.731458
# [59]	train-auc:0.746433	eval-auc:0.731473
# ...
# [251]	train-auc:0.762015	eval-auc:0.738369
# [252]	train-auc:0.762068	eval-auc:0.738383
# [253]	train-auc:0.762098	eval-auc:0.738388
# [254]	train-auc:0.762175	eval-auc:0.738426
# [255]	train-auc:0.762238	eval-auc:0.738437
# [256]	train-auc:0.762292	eval-auc:0.738451
# [257]	train-auc:0.762352	eval-auc:0.738476
# [258]	train-auc:0.762466	eval-auc:0.738509
# [259]	train-auc:0.76258	eval-auc:0.738562
# [260]	train-auc:0.76264	eval-auc:0.738582
# [261]	train-auc:0.762713	eval-auc:0.738601
# [262]	train-auc:0.762759	eval-auc:0.738605
# [263]	train-auc:0.762862	eval-auc:0.73861
# [264]	train-auc:0.762911	eval-auc:0.738624
# [265]	train-auc:0.763005	eval-auc:0.738652
# [266]	train-auc:0.763111	eval-auc:0.738665
# [267]	train-auc:0.763188	eval-auc:0.73868
# [268]	train-auc:0.763242	eval-auc:0.738696
# [269]	train-auc:0.763326	eval-auc:0.738716
# [270]	train-auc:0.763341	eval-auc:0.738715
# [271]	train-auc:0.763391	eval-auc:0.738736
# [272]	train-auc:0.763472	eval-auc:0.738745
# [273]	train-auc:0.763546	eval-auc:0.73877
# [274]	train-auc:0.763611	eval-auc:0.738797
# [275]	train-auc:0.763675	eval-auc:0.738816
# [276]	train-auc:0.763746	eval-auc:0.738835
# [277]	train-auc:0.763845	eval-auc:0.73885
# [278]	train-auc:0.76394	eval-auc:0.738858
# [279]	train-auc:0.764018	eval-auc:0.738887
# [280]	train-auc:0.764127	eval-auc:0.7389
# [281]	train-auc:0.764153	eval-auc:0.738899
# [282]	train-auc:0.764247	eval-auc:0.738928
# [283]	train-auc:0.764322	eval-auc:0.738935
# [284]	train-auc:0.764372	eval-auc:0.738953
# [285]	train-auc:0.764401	eval-auc:0.738946
# [286]	train-auc:0.764448	eval-auc:0.738965
# [287]	train-auc:0.76451	eval-auc:0.738972
# [288]	train-auc:0.764595	eval-auc:0.738983
# [289]	train-auc:0.764698	eval-auc:0.738991
# [290]	train-auc:0.764792	eval-auc:0.738995
# [291]	train-auc:0.764902	eval-auc:0.739011
# [292]	train-auc:0.764997	eval-auc:0.739026
# [293]	train-auc:0.765029	eval-auc:0.73903
# [294]	train-auc:0.76508	eval-auc:0.739049
# [295]	train-auc:0.765147	eval-auc:0.739044
# [296]	train-auc:0.76526	eval-auc:0.739078
# [297]	train-auc:0.765375	eval-auc:0.739104
# [298]	train-auc:0.765413	eval-auc:0.739102
# [299]	train-auc:0.765452	eval-auc:0.739101
# [300]	train-auc:0.765513	eval-auc:0.739102
# [301]	train-auc:0.765535	eval-auc:0.739098
# [302]	train-auc:0.765576	eval-auc:0.739091
# [303]	train-auc:0.765645	eval-auc:0.739088
# [304]	train-auc:0.765723	eval-auc:0.739085
# [305]	train-auc:0.765832	eval-auc:0.739091
# [306]	train-auc:0.765867	eval-auc:0.739102
# [307]	train-auc:0.766	eval-auc:0.739122
# [308]	train-auc:0.76603	eval-auc:0.739138
# [309]	train-auc:0.766066	eval-auc:0.739137
# [310]	train-auc:0.766112	eval-auc:0.739138
# [311]	train-auc:0.766165	eval-auc:0.739157
# [312]	train-auc:0.766296	eval-auc:0.739177
# [313]	train-auc:0.766329	eval-auc:0.739186
# [314]	train-auc:0.766385	eval-auc:0.739198
# [315]	train-auc:0.766444	eval-auc:0.739223
# [316]	train-auc:0.766492	eval-auc:0.739228
# [317]	train-auc:0.766545	eval-auc:0.739241
# [318]	train-auc:0.766599	eval-auc:0.73927
# [319]	train-auc:0.76664	eval-auc:0.739273
# [320]	train-auc:0.766679	eval-auc:0.739269
# [321]	train-auc:0.766742	eval-auc:0.739267
# [322]	train-auc:0.766818	eval-auc:0.739272
# [323]	train-auc:0.766869	eval-auc:0.739291
# [324]	train-auc:0.766912	eval-auc:0.739287
# [325]	train-auc:0.76696	eval-auc:0.739291
# [326]	train-auc:0.767028	eval-auc:0.739299
# [327]	train-auc:0.767114	eval-auc:0.739306
# [328]	train-auc:0.767178	eval-auc:0.739312
# [329]	train-auc:0.767222	eval-auc:0.739325
# [330]	train-auc:0.76727	eval-auc:0.739346
# [331]	train-auc:0.767359	eval-auc:0.739363
# [332]	train-auc:0.767429	eval-auc:0.739361
# [333]	train-auc:0.767501	eval-auc:0.739367
# [334]	train-auc:0.767569	eval-auc:0.739367
# [335]	train-auc:0.76761	eval-auc:0.739391
# [336]	train-auc:0.767714	eval-auc:0.739402
# [337]	train-auc:0.767785	eval-auc:0.739422
# [338]	train-auc:0.767831	eval-auc:0.739398
# [339]	train-auc:0.767894	eval-auc:0.739418
# [340]	train-auc:0.767945	eval-auc:0.739415
# [341]	train-auc:0.76799	eval-auc:0.739423
# [342]	train-auc:0.768055	eval-auc:0.739427
# [343]	train-auc:0.768118	eval-auc:0.739413
# [344]	train-auc:0.768181	eval-auc:0.739426
# [345]	train-auc:0.768228	eval-auc:0.739435
# [346]	train-auc:0.768336	eval-auc:0.73946
# [347]	train-auc:0.768392	eval-auc:0.739487
# [348]	train-auc:0.768466	eval-auc:0.739485
# [349]	train-auc:0.768507	eval-auc:0.73948
# [350]	train-auc:0.768591	eval-auc:0.739475
# [351]	train-auc:0.768626	eval-auc:0.739476
# [352]	train-auc:0.768671	eval-auc:0.739489
# [353]	train-auc:0.768779	eval-auc:0.739482
# [354]	train-auc:0.768827	eval-auc:0.739482
# [355]	train-auc:0.768905	eval-auc:0.739496
# [356]	train-auc:0.768955	eval-auc:0.739505
# [357]	train-auc:0.768999	eval-auc:0.739498
# [358]	train-auc:0.769063	eval-auc:0.739496
# [359]	train-auc:0.769098	eval-auc:0.739502
# [360]	train-auc:0.769181	eval-auc:0.739511
# [361]	train-auc:0.769296	eval-auc:0.739519
# [362]	train-auc:0.769361	eval-auc:0.739508
# [363]	train-auc:0.769383	eval-auc:0.739506
# [364]	train-auc:0.769428	eval-auc:0.739511
# [365]	train-auc:0.769548	eval-auc:0.739537
# [366]	train-auc:0.769579	eval-auc:0.739546
# [367]	train-auc:0.769604	eval-auc:0.739554
# [368]	train-auc:0.769666	eval-auc:0.739556
# [369]	train-auc:0.7697	eval-auc:0.739564
# [370]	train-auc:0.769779	eval-auc:0.739565
# [371]	train-auc:0.76984	eval-auc:0.739569
# [372]	train-auc:0.769925	eval-auc:0.739562
# [373]	train-auc:0.76996	eval-auc:0.739551
# [374]	train-auc:0.770016	eval-auc:0.739581
# [375]	train-auc:0.770067	eval-auc:0.739573
# [376]	train-auc:0.770107	eval-auc:0.739589
# [377]	train-auc:0.770146	eval-auc:0.739579
# [378]	train-auc:0.770171	eval-auc:0.739575
# [379]	train-auc:0.770243	eval-auc:0.739578
# [380]	train-auc:0.770275	eval-auc:0.739595
# [381]	train-auc:0.770316	eval-auc:0.739593
# [382]	train-auc:0.770418	eval-auc:0.739594
# [383]	train-auc:0.770461	eval-auc:0.739596
# [384]	train-auc:0.770481	eval-auc:0.739597
# [385]	train-auc:0.770518	eval-auc:0.739608
# [386]	train-auc:0.77056	eval-auc:0.739598
# [387]	train-auc:0.770639	eval-auc:0.739615
# [388]	train-auc:0.770717	eval-auc:0.739631
# [389]	train-auc:0.770765	eval-auc:0.739646
# [390]	train-auc:0.770797	eval-auc:0.739661
# [391]	train-auc:0.770828	eval-auc:0.739656
# [392]	train-auc:0.770883	eval-auc:0.739654
# [393]	train-auc:0.770959	eval-auc:0.739668
# [394]	train-auc:0.771053	eval-auc:0.739649
# [395]	train-auc:0.771074	eval-auc:0.73966
# [396]	train-auc:0.7711	eval-auc:0.739654
# [397]	train-auc:0.77115	eval-auc:0.739653
# [398]	train-auc:0.771197	eval-auc:0.739676
# [399]	train-auc:0.771235	eval-auc:0.739678
# [400]	train-auc:0.771293	eval-auc:0.739678
# [401]	train-auc:0.771372	eval-auc:0.739711
# [402]	train-auc:0.771414	eval-auc:0.739704
# [403]	train-auc:0.771461	eval-auc:0.739716
# [404]	train-auc:0.771485	eval-auc:0.739719
# [405]	train-auc:0.771553	eval-auc:0.739742
# [406]	train-auc:0.771599	eval-auc:0.739732
# [407]	train-auc:0.771644	eval-auc:0.739737
# [408]	train-auc:0.77169	eval-auc:0.739733
# [409]	train-auc:0.771712	eval-auc:0.739737
# [410]	train-auc:0.771752	eval-auc:0.739745
# [411]	train-auc:0.771782	eval-auc:0.739744
# [412]	train-auc:0.771811	eval-auc:0.739744
# [413]	train-auc:0.77184	eval-auc:0.739741
# [414]	train-auc:0.77194	eval-auc:0.739762
# [415]	train-auc:0.771959	eval-auc:0.739761
# [416]	train-auc:0.771997	eval-auc:0.739772
# [417]	train-auc:0.772033	eval-auc:0.739767
# [418]	train-auc:0.77212	eval-auc:0.739774
# [419]	train-auc:0.772162	eval-auc:0.739759
# [420]	train-auc:0.772193	eval-auc:0.739756
# [421]	train-auc:0.772253	eval-auc:0.739761
# [422]	train-auc:0.772272	eval-auc:0.739763
# [423]	train-auc:0.772332	eval-auc:0.739759
# [424]	train-auc:0.772397	eval-auc:0.739776
# [425]	train-auc:0.772428	eval-auc:0.739784
# [426]	train-auc:0.772478	eval-auc:0.739785
# [427]	train-auc:0.772526	eval-auc:0.739781
# [428]	train-auc:0.772563	eval-auc:0.739802
# [429]	train-auc:0.772641	eval-auc:0.739816
# [430]	train-auc:0.772657	eval-auc:0.73981
# [431]	train-auc:0.772699	eval-auc:0.73981
# [432]	train-auc:0.772748	eval-auc:0.739816
# [433]	train-auc:0.772803	eval-auc:0.739825
# [434]	train-auc:0.772821	eval-auc:0.739827
# [435]	train-auc:0.772857	eval-auc:0.739812
# [436]	train-auc:0.772924	eval-auc:0.739813
# [437]	train-auc:0.77298	eval-auc:0.739808
# [438]	train-auc:0.773017	eval-auc:0.739792
# [439]	train-auc:0.773128	eval-auc:0.739806
# [440]	train-auc:0.773187	eval-auc:0.739796
# [441]	train-auc:0.773208	eval-auc:0.739803
# [442]	train-auc:0.773226	eval-auc:0.739809
# [443]	train-auc:0.773245	eval-auc:0.739807
# [444]	train-auc:0.773354	eval-auc:0.739825
# [445]	train-auc:0.773403	eval-auc:0.739814
# [446]	train-auc:0.77344	eval-auc:0.739815
# [447]	train-auc:0.773539	eval-auc:0.739828
# [448]	train-auc:0.773569	eval-auc:0.739829
# [449]	train-auc:0.773638	eval-auc:0.739826
# [450]	train-auc:0.773649	eval-auc:0.739827
# [451]	train-auc:0.773704	eval-auc:0.739819
# [452]	train-auc:0.773746	eval-auc:0.739828
# [453]	train-auc:0.773766	eval-auc:0.739822
# [454]	train-auc:0.773832	eval-auc:0.739809
# [455]	train-auc:0.773875	eval-auc:0.739801
# [456]	train-auc:0.773887	eval-auc:0.739798
# [457]	train-auc:0.773929	eval-auc:0.739813
# [458]	train-auc:0.773967	eval-auc:0.739818
# [459]	train-auc:0.774014	eval-auc:0.739834
# [460]	train-auc:0.774041	eval-auc:0.739839
# [461]	train-auc:0.774103	eval-auc:0.739845
# [462]	train-auc:0.774121	eval-auc:0.739845
# [463]	train-auc:0.774176	eval-auc:0.739856
# [464]	train-auc:0.774223	eval-auc:0.739848
# [465]	train-auc:0.774281	eval-auc:0.739866
# [466]	train-auc:0.774295	eval-auc:0.739854
# [467]	train-auc:0.774375	eval-auc:0.739872
# [468]	train-auc:0.774427	eval-auc:0.739864
# [469]	train-auc:0.774448	eval-auc:0.73988
# [470]	train-auc:0.774463	eval-auc:0.739875
# [471]	train-auc:0.774487	eval-auc:0.739871
# [472]	train-auc:0.774524	eval-auc:0.739872
# [473]	train-auc:0.77458	eval-auc:0.739865
# [474]	train-auc:0.774629	eval-auc:0.739866
# [475]	train-auc:0.774672	eval-auc:0.739864
# [476]	train-auc:0.774725	eval-auc:0.739861
# [477]	train-auc:0.774761	eval-auc:0.739864
# [478]	train-auc:0.774832	eval-auc:0.739889
# [479]	train-auc:0.774894	eval-auc:0.739896
# [480]	train-auc:0.774904	eval-auc:0.739884
# [481]	train-auc:0.774946	eval-auc:0.739869
# [482]	train-auc:0.774982	eval-auc:0.739873
# [483]	train-auc:0.775002	eval-auc:0.739873
# [484]	train-auc:0.775033	eval-auc:0.739889
# [485]	train-auc:0.775081	eval-auc:0.739874
# [486]	train-auc:0.775134	eval-auc:0.739882
# [487]	train-auc:0.775179	eval-auc:0.739875
# [488]	train-auc:0.775252	eval-auc:0.739905
# [489]	train-auc:0.775285	eval-auc:0.739915
# [490]	train-auc:0.775312	eval-auc:0.739908
# [491]	train-auc:0.775356	eval-auc:0.739931
# [492]	train-auc:0.775394	eval-auc:0.739929
# [493]	train-auc:0.775429	eval-auc:0.739929
# [494]	train-auc:0.775473	eval-auc:0.739938
# [495]	train-auc:0.775527	eval-auc:0.739952
# [496]	train-auc:0.775579	eval-auc:0.739956
# [497]	train-auc:0.775617	eval-auc:0.73995
# [498]	train-auc:0.775695	eval-auc:0.739963
# [499]	train-auc:0.77571	eval-auc:0.739971
# [500]	train-auc:0.775741	eval-auc:0.739954
# [501]	train-auc:0.775834	eval-auc:0.739971
# [502]	train-auc:0.775861	eval-auc:0.739962
# [503]	train-auc:0.775874	eval-auc:0.73995
# [504]	train-auc:0.77593	eval-auc:0.739961
# [505]	train-auc:0.776022	eval-auc:0.73998
# [506]	train-auc:0.776088	eval-auc:0.739987
# [507]	train-auc:0.776188	eval-auc:0.73999
# [508]	train-auc:0.776221	eval-auc:0.739987
# [509]	train-auc:0.776284	eval-auc:0.73998
# [510]	train-auc:0.776351	eval-auc:0.739985
# [511]	train-auc:0.776401	eval-auc:0.739982
# [512]	train-auc:0.776436	eval-auc:0.739979
# [513]	train-auc:0.776465	eval-auc:0.739976
# [514]	train-auc:0.776528	eval-auc:0.739986
# [515]	train-auc:0.776599	eval-auc:0.739992
# [516]	train-auc:0.776687	eval-auc:0.740008
# [517]	train-auc:0.776709	eval-auc:0.740001
# [518]	train-auc:0.776738	eval-auc:0.73999
# [519]	train-auc:0.776785	eval-auc:0.739984
# [520]	train-auc:0.776797	eval-auc:0.739987
# [521]	train-auc:0.776878	eval-auc:0.740012
# [522]	train-auc:0.776928	eval-auc:0.740013
# [523]	train-auc:0.777014	eval-auc:0.740025
# [524]	train-auc:0.777035	eval-auc:0.740016
# [525]	train-auc:0.777089	eval-auc:0.740021
# [526]	train-auc:0.777157	eval-auc:0.740042
# [527]	train-auc:0.777225	eval-auc:0.740039
# [528]	train-auc:0.77728	eval-auc:0.740045
# [529]	train-auc:0.777295	eval-auc:0.740032
# [530]	train-auc:0.777318	eval-auc:0.740037
# [531]	train-auc:0.777368	eval-auc:0.74004
# [532]	train-auc:0.777414	eval-auc:0.740035
# [533]	train-auc:0.777435	eval-auc:0.740036
# [534]	train-auc:0.777487	eval-auc:0.740032
# [535]	train-auc:0.777601	eval-auc:0.740036
# [536]	train-auc:0.777654	eval-auc:0.740044
# [537]	train-auc:0.777688	eval-auc:0.740048
# [538]	train-auc:0.777706	eval-auc:0.740036
# [539]	train-auc:0.777726	eval-auc:0.740037
# [540]	train-auc:0.777781	eval-auc:0.740044
# [541]	train-auc:0.777847	eval-auc:0.740063
# [542]	train-auc:0.777864	eval-auc:0.740063
# [543]	train-auc:0.777882	eval-auc:0.740062
# [544]	train-auc:0.778015	eval-auc:0.740064
# [545]	train-auc:0.778087	eval-auc:0.740066
# [546]	train-auc:0.778106	eval-auc:0.740074
# [547]	train-auc:0.778129	eval-auc:0.740074
# [548]	train-auc:0.778214	eval-auc:0.74011
# [549]	train-auc:0.77827	eval-auc:0.740113
# [550]	train-auc:0.778297	eval-auc:0.740108
# [551]	train-auc:0.778321	eval-auc:0.740107
# [552]	train-auc:0.778379	eval-auc:0.740121
# [553]	train-auc:0.778435	eval-auc:0.740135
# [554]	train-auc:0.778482	eval-auc:0.740129
# [555]	train-auc:0.778514	eval-auc:0.740129
# [556]	train-auc:0.778549	eval-auc:0.740132
# [557]	train-auc:0.778576	eval-auc:0.740139
# [558]	train-auc:0.778644	eval-auc:0.740155
# [559]	train-auc:0.778683	eval-auc:0.740159
# [560]	train-auc:0.778731	eval-auc:0.740152
# [561]	train-auc:0.77878	eval-auc:0.74015
# [562]	train-auc:0.778858	eval-auc:0.74016
# [563]	train-auc:0.778944	eval-auc:0.740171
# [564]	train-auc:0.778979	eval-auc:0.74017
# [565]	train-auc:0.778988	eval-auc:0.740159
# [566]	train-auc:0.779001	eval-auc:0.740165
# [567]	train-auc:0.779049	eval-auc:0.740178
# [568]	train-auc:0.77909	eval-auc:0.740207
# [569]	train-auc:0.779123	eval-auc:0.740204
# [570]	train-auc:0.779149	eval-auc:0.740216
# [571]	train-auc:0.779177	eval-auc:0.740217
# [572]	train-auc:0.779201	eval-auc:0.740219
# [573]	train-auc:0.779211	eval-auc:0.740211
# [574]	train-auc:0.77923	eval-auc:0.740206
# [575]	train-auc:0.779257	eval-auc:0.74021
# [576]	train-auc:0.779311	eval-auc:0.740212
# [577]	train-auc:0.779331	eval-auc:0.74021
# [578]	train-auc:0.779448	eval-auc:0.740205
# [579]	train-auc:0.779473	eval-auc:0.740208
# [580]	train-auc:0.779492	eval-auc:0.74021
# [581]	train-auc:0.779536	eval-auc:0.740213
# [582]	train-auc:0.779551	eval-auc:0.74021
# [583]	train-auc:0.779684	eval-auc:0.740224
# [584]	train-auc:0.779692	eval-auc:0.740215
# [585]	train-auc:0.779763	eval-auc:0.740225
# [586]	train-auc:0.779831	eval-auc:0.740229
# [587]	train-auc:0.779887	eval-auc:0.74022
# [588]	train-auc:0.779903	eval-auc:0.740215
# [589]	train-auc:0.779924	eval-auc:0.74022
# [590]	train-auc:0.77994	eval-auc:0.740226
# [591]	train-auc:0.779972	eval-auc:0.740232
# [592]	train-auc:0.780012	eval-auc:0.740231
# [593]	train-auc:0.780051	eval-auc:0.740237
# [594]	train-auc:0.780081	eval-auc:0.740236
# [595]	train-auc:0.780117	eval-auc:0.740235
# [596]	train-auc:0.780154	eval-auc:0.740229
# [597]	train-auc:0.78019	eval-auc:0.740224
# [598]	train-auc:0.780219	eval-auc:0.740218
# [599]	train-auc:0.780244	eval-auc:0.740218
# [600]	train-auc:0.780311	eval-auc:0.740212
# [601]	train-auc:0.780336	eval-auc:0.740224
# [602]	train-auc:0.780364	eval-auc:0.74021
# [603]	train-auc:0.780385	eval-auc:0.740217
# [604]	train-auc:0.780397	eval-auc:0.740207
# [605]	train-auc:0.780424	eval-auc:0.740205
# [606]	train-auc:0.780486	eval-auc:0.740213
# [607]	train-auc:0.780551	eval-auc:0.740209
# [608]	train-auc:0.780581	eval-auc:0.740215
# [609]	train-auc:0.780599	eval-auc:0.740209
# [610]	train-auc:0.780624	eval-auc:0.740216
# [611]	train-auc:0.780644	eval-auc:0.740218
# [612]	train-auc:0.780667	eval-auc:0.74022
# [613]	train-auc:0.780679	eval-auc:0.740215
# Stopping. Best iteration:
# [593]	train-auc:0.780051	eval-auc:0.740237
#
# ==================================================
#  TRAIN
# --------------------------------------------------
# # Brier   : 0.0816 + 0.08
# # AUC     : 0.7779 + 0.78
# # Logloss : 0.2809 + 0.28
# ==================================================
#  VALID
# --------------------------------------------------
# # Brier   : 0.0844 + 0.08
# # AUC     : 0.7433 + 0.74
# # Logloss : 0.2927 + 0.29

# %% [markdown]
# # Visualization
#     - retrieve feature importance and plot
#         - for random forest model
#         - for linear (logistic regression) model
#         - for xgboost model

# %%
# RandomForest

print('='*50)
print(model)

feature_importance = dict()
for i, f_imp in enumerate(model.feature_importances_):
    feature_importance[features[i]] = f_imp

print('-'*50)
print('# Sorted Feature Importance')
feature_importance_sorted = sorted(feature_importance.items(), key=operator.itemgetter(1), reverse=True)
prefix = '    '
for item in feature_importance_sorted:
    print('{} {} \t {}'.format(prefix, round(item[1],5), item[0]))

# plot
fimp = feature_importance_sorted
plot_x = []; plot_y = []
for item in fimp:
    plot_x.append(item[0])
    plot_y.append(item[1])

f, ax = plt.subplots(figsize=(20, 15))
sns.barplot(plot_x,plot_y,alpha=0.5)
ax.set_title('Feature Importance for Model : RandomForest Tree')
ax.set(xlabel='Column Name', ylabel='Feature Importance')
# Out:
# ==================================================
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=10, n_jobs=-1, oob_score=False, random_state=777,
#             verbose=0, warm_start=False)
# --------------------------------------------------
# # Sorted Feature Importance
#      0.25455 	 int_rate
#      0.20537 	 issue_datestamp
#      0.19704 	 sub_grade
#      0.16178 	 grade
#      0.0496 	 issue_y
#      0.02537 	 initial_list_status
#      0.01404 	 term
#      0.01385 	 annual_inc
#      0.0105 	 dti
#      0.0103 	 installment
#      0.00891 	 inq_last_6mths
#      0.00853 	 home_ownership
#      0.00673 	 verification_status
#      0.00564 	 revol_util
#      0.00433 	 issue_m
#      0.0042 	 loan_amnt
#      0.00416 	 zip_code
#      0.00297 	 total_acc
#      0.00248 	 emp_length
#      0.00243 	 annual_inc_bin
#      0.00214 	 early_cr_datestamp
#      0.00192 	 earliest_cr_line_y
#      0.0013 	 open_acc
#      0.00081 	 addr_state
#      0.00052 	 delinq_2yrs
#      0.00031 	 pub_rec
#      0.00025 	 purpose
#      0.0 	 application_type
#      0.0 	 earliest_cr_line_m
# [<matplotlib.text.Text at 0x10b3cbba8>, <matplotlib.text.Text at 0x10b3da7f0>]

# %%
# Logistic Regression

target_num = 0
print('='*50)
print(model)

print('='*50)
print('# Coefficients for target_num == {}'.format(target_num))
print(model.coef_[target_num])

feature_importance = dict()
for i, f_imp in enumerate(model.coef_[target_num]):
    feature_importance[features[i]] = f_imp

print('-'*50)
print('# Sorted Feature Importance')
coefs_sorted = sorted(feature_importance.items(), key=operator.itemgetter(1), reverse=True)
for item in coefs_sorted:
    print('{} {} \t {}'.format(prefix, round(item[1],5), item[0]))

plot_x = []; plot_y = []
for item in coefs_sorted:
    plot_x.append(item[0])
    plot_y.append(item[1])

f, ax = plt.subplots(figsize=(15, 10))
sns.barplot(plot_x,plot_y,alpha=0.5)
ax.set_title('Feature Importance for Model : Logistic Regression')
ax.set_xticklabels(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set(xlabel='Column Name', ylabel='Feature Importance')
# Out:
# ==================================================
# LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# ==================================================
# # Coefficients for target_num == 0
# [  1.94801413e-03   4.24700276e-02   1.23639008e-02   6.35420191e-02
#   -7.20387596e-03   8.71850417e-03   2.76005143e-03  -1.37881264e-03
#   -2.03529593e-03   2.09310869e-03  -1.34312074e-04  -6.83393952e-04
#   -1.72438738e-03  -1.46002145e-05  -5.29730024e-04  -1.41014763e-03
#   -7.92079542e-05   2.38288230e-02  -1.62004441e-04  -1.89671611e-03
#   -1.09554102e-05   5.73354026e-04  -2.42533172e-06   1.12995074e-02
#    1.02127668e-03   6.26314422e-03   3.34234484e-03   6.15525919e-04
#    2.30250920e-03]
# --------------------------------------------------
# # Sorted Feature Importance
#      0.06354 	 sub_grade
#      0.04247 	 int_rate
#      0.02383 	 issue_datestamp
#      0.01236 	 grade
#      0.0113 	 dti
#      0.00872 	 home_ownership
#      0.00626 	 inq_last_6mths
#      0.00334 	 open_acc
#      0.00276 	 verification_status
#      0.0023 	 total_acc
#      0.00209 	 purpose
#      0.00195 	 term
#      0.00102 	 delinq_2yrs
#      0.00062 	 pub_rec
#      0.00057 	 installment
#      -0.0 	 annual_inc
#      -1e-05 	 loan_amnt
#      -1e-05 	 earliest_cr_line_y
#      -8e-05 	 application_type
#      -0.00013 	 zip_code
#      -0.00016 	 early_cr_datestamp
#      -0.00053 	 revol_util
#      -0.00068 	 addr_state
#      -0.00138 	 issue_m
#      -0.00141 	 initial_list_status
#      -0.00172 	 earliest_cr_line_m
#      -0.0019 	 annual_inc_bin
#      -0.00204 	 issue_y
#      -0.0072 	 emp_length
# [<matplotlib.text.Text at 0x10a5b8f98>, <matplotlib.text.Text at 0x10a5b6ef0>]

# %% [markdown]
# # Feature importance_xgboost

# %%
print('='*50)

print('-'*50)
print('# Sorted Feature Importance')
feature_importance_sorted = sorted(xgb_model.get_fscore().items(), key=operator.itemgetter(1), reverse=True)
prefix = '    '
for item in feature_importance_sorted:
    print('{} {} \t {}'.format(prefix, round(item[1],5), item[0]))

# plot
fimp = feature_importance_sorted
plot_x = []; plot_y = []
for item in fimp:
    plot_x.append(item[0])
    plot_y.append(item[1])

f, ax = plt.subplots(figsize=(20, 15))
sns.barplot(plot_x,plot_y,alpha=0.5)
ax.set_title('Feature Importance for Model : XGBoost Tree')
ax.set(xlabel='Column Name', ylabel='Feature Importance')
# Out:
# ==================================================
# --------------------------------------------------
# # Sorted Feature Importance
#      1574 	 issue_datestamp
#      1160 	 int_rate
#      1083 	 annual_inc
#      1011 	 installment
#      995 	 dti
#      749 	 sub_grade
#      722 	 zip_code
#      672 	 revol_util
#      599 	 early_cr_datestamp
#      593 	 total_acc
#      585 	 loan_amnt
#      465 	 emp_length
#      459 	 issue_m
#      408 	 open_acc
#      383 	 inq_last_6mths
#      313 	 addr_state
#      306 	 home_ownership
#      264 	 issue_y
#      251 	 purpose
#      195 	 grade
#      172 	 earliest_cr_line_m
#      155 	 earliest_cr_line_y
#      124 	 term
#      108 	 delinq_2yrs
#      98 	 verification_status
#      76 	 pub_rec
#      75 	 initial_list_status
#      73 	 annual_inc_bin
#      34 	 application_type
# [<matplotlib.text.Text at 0x10c9d99b0>, <matplotlib.text.Text at 0x10b3cecc0>]

# %% [markdown]
# # outlier detection
#     - feature wise histogram used to observe the spread and detect outlier
#         - annual_inc, dti had skewed distribution with extreme values

# %%
for feature in features:
    print('# Col : {}'.format(feature))
    sns.distplot(data[feature], kde=False)
    plt.show()
# Out:
# # Col : term
# # Col : int_rate
# # Col : grade
# # Col : sub_grade
# # Col : emp_length
# # Col : home_ownership
# # Col : verification_status
# # Col : issue_m
# # Col : issue_y
# # Col : purpose
# # Col : zip_code
# # Col : addr_state
# # Col : earliest_cr_line_m
# # Col : earliest_cr_line_y
# # Col : revol_util
# # Col : initial_list_status
# # Col : application_type
# # Col : issue_datestamp
# # Col : early_cr_datestamp
# # Col : annual_inc_bin
# # Col : loan_amnt
# # Col : installment
# # Col : annual_inc
# # Col : dti
# # Col : delinq_2yrs
# # Col : inq_last_6mths
# # Col : open_acc
# # Col : pub_rec
# # Col : total_acc

# %%
# single data observation
data.loc[122]
# Out:
# id                                                              40531664
# member_id                                                       43396438
# loan_amnt                                                          12000
# funded_amnt                                                        12000
# funded_amnt_inv                                                    12000
# term                                                                   0
# int_rate                                                            8.19
# installment                                                       376.89
# grade                                                                  0
# sub_grade                                                              4
# emp_title                                               MACHINE OPERATOR
# emp_length                                                            10
# home_ownership                                                         4
# annual_inc                                                         38000
# verification_status                                                    0
# issue_d                                                         Feb-2015
# loan_status                                                   Fully Paid
# url                    https://lendingclub.com/browse/loanDetail.acti...
# desc                                                                 NaN
# purpose                                                                1
# title                                            Credit card refinancing
# zip_code                                                             496
# addr_state                                                            23
# dti                                                                21.32
# delinq_2yrs                                                            0
# earliest_cr_line                                                Dec-1998
# inq_last_6mths                                                         0
# open_acc                                                              12
# pub_rec                                                                0
# revol_util                                                          31.5
# total_acc                                                             39
# initial_list_status                                                    1
# application_type                                                       1
# issue_m                                                                2
# issue_y                                                             2015
# earliest_cr_line_m                                                    12
# earliest_cr_line_y                                                  1998
# issue_datestamp                                                       24
# early_cr_datestamp                                                  1298
# annual_inc_bin                                                         3
# Name: 122, dtype: object

# %% [markdown]
# # Making submission

# %%
# fit all data
model.fit(trn, y)

# make prediction on test
prediction = model.predict_proba(tst.as_matrix(columns=features))[:,1]

# output to file
submission = pd.DataFrame(prediction, columns=['prediction'])
filename = '../output/anything_random_valid_{0:.4f}.csv'.format(np.mean(vld_bri))
submission.to_csv(filename, index=False)

# %%
# fit all data
dtrn = xgb.DMatrix(data.as_matrix(columns=features), label=y, feature_names=features)
model = xgb.train(param, dtrn, int(np.mean(best_ntree)*1.5))
    
# make prediction on test
dtst = xgb.DMatrix(tst.as_matrix(columns=features), feature_names=features)
prediction = model.predict(dtst)

# output to file
submission = pd.DataFrame(prediction, columns=['prediction'])
filename = '../output/anything_random_valid_{0:.4f}.csv'.format(np.mean(vld_bri))
submission.to_csv(filename, index=False)

# this code generates our final prediction file!

# %% [markdown]
# # train-valid-test relationship
#     - violin plot of features in trn/vld/tst data
#     - visualization confirms that all three data come from similar distribution, implying that the performance of trn/vld can be generalized to test data

# %%
# extract cross-validation split index
skf = StratifiedKFold(n_splits=3)
for trn_index, vld_index in skf.split(trn, y):
    pass
 
# iterate over features for violin plot
for col in features:
    print('='*50)
    print('col : ', col)

    # retrieve trn/vld/tst data
    trn_tmp = pd.DataFrame(data.ix[trn_index, col])
    vld_tmp = pd.DataFrame(data.ix[vld_index, col])
    tst_tmp = pd.DataFrame(tst[col])
    
    # give state label
    trn_tmp['state'] = 'train'
    vld_tmp['state'] = 'valid'
    tst_tmp['state'] = 'test'
    
    # concatenate all
    tmp = pd.concat([trn_tmp, vld_tmp, tst_tmp], axis=0)

    # plot
    sns.violinplot(x="state", y=col, data=tmp)
    plt.show()
# Out:
# ==================================================
# col :  term
# ==================================================
# col :  int_rate
# ==================================================
# col :  grade
# ==================================================
# col :  sub_grade
# ==================================================
# col :  emp_length
# ==================================================
# col :  home_ownership
# ==================================================
# col :  verification_status
# ==================================================
# col :  issue_m
# ==================================================
# col :  issue_y
# ==================================================
# col :  purpose
# ==================================================
# col :  zip_code
# ==================================================
# col :  addr_state
# ==================================================
# col :  earliest_cr_line_m
# ==================================================
# col :  earliest_cr_line_y
# ==================================================
# col :  revol_util
# ==================================================
# col :  initial_list_status
# ==================================================
# col :  application_type
# ==================================================
# col :  issue_datestamp
# ==================================================
# col :  early_cr_datestamp
# ==================================================
# col :  annual_inc_bin
# ==================================================
# col :  loan_amnt
# ==================================================
# col :  installment
# ==================================================
# col :  annual_inc
# ==================================================
# col :  dti
# ==================================================
# col :  delinq_2yrs
# ==================================================
# col :  inq_last_6mths
# ==================================================
# col :  open_acc
# ==================================================
# col :  pub_rec
# ==================================================
# col :  total_acc
